# %%
using Distributions, TimeIt, ProgressMeter, PyPlot
include("/home/postdoc/dsen/Desktop/codes/G-ZZ_clean/jl_files/zz_samplers.jl")
include("/home/postdoc/dsen/Desktop/codes/G-ZZ_clean/jl_files/mbsampler.jl")
# Out:
# get_clustering (generic function with 1 method)

# %%
d, Nobs = 5, 20
X = randn(d, Nobs)
X[1,:] = ones(Nobs)
ξ_true = rand(Normal(),d).* rand(Binomial(1,0.5), d)
ξ_true[1] = rand(Normal())
y = [rand(Binomial(1, 1/(1+exp(-ξ_true'X[:,j])))) + 0. for j in 1:Nobs];
σ02 = 1;

# %%
prior = gaussian_prior_nh(d, σ02) # non-hierarchical Gaussian prior
my_ll = ll_logistic_sp(X,y);
my_model = model(my_ll, prior);

# %%
ξ0 = zeros(d)
stepsize = 1e-2
n_leapfrog = 100
n_mcmc = 10_000

xi_samples, hyper_samples, acc = GibbsHMC(my_model, ξ0, stepsize, n_leapfrog, n_mcmc);
# Out:
# 10 percent steps in 0.2 min; HMC acceptance = 100 percent
# 20 percent steps in 0.3 min; HMC acceptance = 100 percent
# 30 percent steps in 0.5 min; HMC acceptance = 100 percent
# 40 percent steps in 0.6 min; HMC acceptance = 100 percent
# 50 percent steps in 0.8 min; HMC acceptance = 100 percent
# 60 percent steps in 0.9 min; HMC acceptance = 100 percent
# 70 percent steps in 1.1 min; HMC acceptance = 100 percent
# 80 percent steps in 1.2 min; HMC acceptance = 100 percent
# 90 percent steps in 1.4 min; HMC acceptance = 100 percent
# 100 percent steps in 1.5 min; HMC acceptance = 100 percent

# %%
for i in 1:size(xi_samples,1)
    plot(xi_samples[i,:]) 
end
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
for i in 1:size(xi_samples,1) 
    plot(acf(xi_samples[i,:], 500))
end
grid(true)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# * Configuration temperature should be around 1.

# %%
fig = figure("pyplot_barplot",figsize=(7,2.5))
plot([compute_configT(my_model, xi_samples, hyper_samples, k) for k in 1:d], "o")
grid(true)
# Out:
# PyPlot.Figure(PyObject <Figure size 700x250 with 1 Axes>)
