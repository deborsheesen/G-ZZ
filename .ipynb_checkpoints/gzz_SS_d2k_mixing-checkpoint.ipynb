# %%
using Distributions, TimeIt, ProgressMeter, PyPlot, JLD
include("zz_structures_DuLuSuSe.jl")
include("mbsampler.jl")
# Out:
# get_clustering (generic function with 1 method)

# %% [markdown]
# #### Load data:

# %%
d, Nobs = 2000, 3000
X = sprandn(d, Nobs, 5e-2)
X[1,:] = ones(Nobs)
ξ_true = 3*sprandn(d, 1e-2)
ξ_true[1] = 3*randn()
y = [rand(Binomial(1, 1/(1+exp(-X[:,n]'ξ_true)))) for n in 1:Nobs];

# %% [markdown]
# #### Define prior:

# %%
σ02 = 1
prior = SS_prior(d, σ02);

# %% [markdown]
# #### Define model:

# %%
my_ll = ll_logistic_sp(X,y);
my_model = model(my_ll, prior);

# %% [markdown]
# #### Define minibatch sampler:

# %%
mb_size = 200
weights_het = spzeros(d, Nobs)
@showprogress for i in 1:d 
    nzind = X[i,:].nzind
    weights_het[i,nzind] = abs.(X[i,nzind])./sum(abs.(X[i,nzind]))
end

prob_het = 0.98
gs = Array{mbsampler}(d)
gs[1] = umbsampler(Nobs, mb_size)
@showprogress for i in 2:d 
    gs[i] = spwumbsampler(Nobs, mb_size, weights_het[i,:], prob_het)
end
gs_list = mbsampler_list(d,gs);
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:12
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00

# %% [raw]
# # Sub-Sampling with control variate and with weights
# ϵ = 1e-2
# weights_cv = zeros(d, Nobs)
# for n in 1:Nobs
#     weights_cv[:,n] = [abs.(X[i,n])*norm(X[:,n]) for i in 1:d] + ϵ
# end
# weights_cv ./= sum(weights_cv,2);mbs = [wumbsampler(Nobs, mb_size, weights_cv[i,:]) for i in 1:d];
# gs_list = cvmbsampler_list(my_model, mbs, root);

# %% [markdown]
# #### Define output scheduler:

# %%
k = 100
A_xi = spzeros(k,d)
for i in 1:k 
    A_xi[i,i] = 1
end

# %%
# A_xi = ones(1,d)/d
A_hyp = ones(1,hyperparam_size(prior))/hyperparam_size(prior)
A_xi = eye(d)
# A_hyp = eye(hyperparam_size(prior))

opf = projopf(A_xi, A_hyp, 1000)
opt = maxa_opt(10^6, 2*10^5)
outp = outputscheduler(opf,opt)
bb = linear_bound(my_model.ll, my_model.pr, gs_list)
mstate = zz_state(d)
update_bound(bb, my_ll, prior, gs_list, mstate);

# %% [markdown]
# #### Define mbsampler + block Gibbs sampler list:

# %%
adapt_speed = "by_bounce"
L = 1
my_zz_sampler = zz_sampler(0, gs_list, bb, L, adapt_speed)
hyper_sampler = block_gibbs_sampler(1e3)
blocksampler = Array{msampler}(2)
blocksampler[1] = my_zz_sampler
blocksampler[2] = hyper_sampler;

# %% [markdown]
# #### Run sampler:

# %%
ZZ_block_sample(my_model, outp, blocksampler, mstate);
# Out:
# 10% attempts in 3.1 mins
# 20% attempts in 5.71 mins
# Trimmed after 200000 bouncing attempts
# 30% attempts in 8.38 mins
# 40% attempts in 11.05 mins
# 50% attempts in 13.72 mins
# 60% attempts in 16.54 mins
# 70% attempts in 19.1 mins
# 80% attempts in 21.66 mins
# 90% attempts in 24.25 mins
# 100% attempts in 26.78 mins

# %%
print(maximum(abs.(outp.opf.xi_mu - mstate.mu)), "\n")
print(maximum(abs.(outp.opf.xi_m2 - mstate.m2)))
# Out:
# 0.33559592304168206
# 0.8421493008436851

# %% [markdown]
# * Number of bounces:

# %%
zz_bounces = sum(mstate.n_bounces)
hyp_bounces = outp.opf.tot_bounces-sum(mstate.n_bounces)
@printf("ZZ total bounces: %i, hyper bounces: %i", zz_bounces, hyp_bounces)
# Out:
# ZZ total bounces: 51844, hyper bounces: 3817

# %%
size(outp.opf.xi_skeleton,2)/outp.opt.max_attempts
# Out:
# 0.041514

# %%
post_mean_gzz = outp.opf.xi_mu
# post_median_gzz = median(xi_samples,2);

# %%
fig = figure(figsize=(12,3))
plot(sort(abs.(ξ_true.nzval), rev=true), "o-", markersize=3, label="true signal")
plot(sort(vec(abs.(post_mean_gzz)), rev=true)[1:100], "o-", markersize=3, label="posterior mean")
# plot(sort(vec(abs.(post_median_gzz)), rev=true)[1:50], "o-", markersize=3, label="posterior median")
grid(true)
title("Absolute values of sorted posterior means for GZZ sampler")
legend(ncol=3)
xlabel("Parameter index")
ylabel("Value")
savefig("plots/postmeansdcomplete2K.pdf", format="pdf", dpi=10000, bbox_inches="tight")
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x300 with 1 Axes>)

# %% [raw]
# maximum(abs.(mean(xi_samples,2) - mstate.mu))

# %%
fig = figure(figsize=(12,3))
plot(abs.(ξ_true.nzval), "o-", markersize=3, label="true signal")
plot(vec(abs.(post_mean_gzz))[ξ_true.nzind], "o-", markersize=3, label="posterior mean")
grid(true)
title("Absolute values of posterior means for GZZ sampler")
legend(ncol=3)
xlabel("Parameter index")
ylabel("Value")
savefig("plots/postmeansd2K.pdf", format="pdf", dpi=10000, bbox_inches="tight")
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x300 with 1 Axes>)

# %% [markdown]
# ### ACF's:

# %%
discard = 0
n_samples = 10^4
xi_samples = extract_samples(outp.opf.xi_skeleton[:,discard+1:end], 
                             outp.opf.bt_skeleton[:,discard+1:end], 
                             outp.opf.bt_skeleton[end]/n_samples,
                             "linear")[:,1:end-1];
pr_samples = extract_samples(outp.opf.hyper_skeleton[:,discard+1:end], 
                              outp.opf.bt_skeleton[:,discard+1:end], 
                              outp.opf.bt_skeleton[end]/n_samples,
                              "constant")[:,1:end-1];

# %%
maxlag = 5000
acfs_xi = zeros(d, maxlag)

@showprogress for i in 1:size(xi_samples,1) 
    acfs_xi[i,:] = acf(xi_samples[i,:], maxlag)
end
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:09:27

# %%
fig = figure(figsize=(12,2.5))
for i in 1:size(xi_samples,1) 
    plot(acfs_xi[i,:])
end
grid(true)
title("ACF's for parameters");
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x250 with 1 Axes>)

# %%
minimum(size(xi_samples,2)./sum(acfs_xi[:,1:1000],2)), maximum(size(xi_samples,2)./sum(acfs_xi[:,1:1000],2))
# Out:
# (-2185.691635496581, 1828.7881732656292)

# %%
plot(mstate.α);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
ξ_true.nzind
# Out:
# 20-element Array{Int64,1}:
#     1
#    44
#   226
#   238
#   357
#   527
#   544
#   608
#   616
#   731
#   857
#  1282
#  1293
#  1343
#  1646
#  1653
#  1714
#  1725
#  1739
#  1898

# %%
(1:d)[mstate.α .> 3]
# Out:
# 17-element Array{Int64,1}:
#    44
#   226
#   238
#   357
#   544
#   608
#   616
#   682
#   731
#   857
#  1293
#  1338
#  1343
#  1646
#  1714
#  1725
#  1898
