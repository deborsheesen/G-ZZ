# %%
using Distributions, TimeIt, ProgressMeter, PyPlot, JLD
#include("zz_structures_DuLuSuSe.jl")
#include("mbsampler.jl")

# %% [markdown]
# #### Load data:

# %%
d, Nobs = 10_000, 12_000
X = sprandn(d, Nobs, 1e-1)
X[1,:] = ones(Nobs)
nz = 100
ξ_true = spzeros(d)
ξ_true[1] = 3*rand()
nzind = sample(1:d, nz)
ξ_true[nzind[1:Int(nz/2)]] = rand(Uniform(5,10),Int(nz/2))
ξ_true[nzind[Int(nz/2)+1:end]] = -rand(Uniform(5,10),Int(nz/2));
y = [rand(Binomial(1, 1/(1+exp(-X[:,n]'ξ_true)))) for n in 1:Nobs];

# %%
xxt = X*X'
sum(xxt .== 0.)
# Out:
# 0

# %% [markdown]
# #### Define prior:

# %%
σ02 = 1
prior = SS_prior(d, σ02);

# %% [markdown]
# #### Define model:

# %%
my_ll = ll_logistic_sp(X,y);
my_model = model(my_ll, prior);

# %% [markdown]
# #### Define minibatch sampler:

# %%
mb_size = 120
prob_het = 0.98
gs = Array{mbsampler}(d)
gs[1] = umbsampler(Nobs, mb_size)

@showprogress for i in 2:d 
    weights_het = abs.(X[i,:])./sum(abs.(X[i,:]))
    gs[i] = spwumbsampler(Nobs, mb_size, weights_het, prob_het)
end
gs_list = mbsampler_list(d,gs);
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:16

# %% [raw]
# # Sub-Sampling with control variate and with weights
# ϵ = 1e-2
# weights_cv = zeros(d, Nobs)
# for n in 1:Nobs
#     weights_cv[:,n] = [abs.(X[i,n])*norm(X[:,n]) for i in 1:d] + ϵ
# end
# weights_cv ./= sum(weights_cv,2);mbs = [wumbsampler(Nobs, mb_size, weights_cv[i,:]) for i in 1:d];
# gs_list = cvmbsampler_list(my_model, mbs, root);

# %% [markdown]
# #### Define output scheduler:

# %%
A_xi = ones(1,d)/d
A_hyp = ones(1,hyperparam_size(prior))/hyperparam_size(prior)

opf = projopf(A_xi, A_hyp, 1000)
opt = maxa_opt(3*10^4, 10^4)
outp = outputscheduler(opf,opt)
bb = linear_bound(my_model.ll, my_model.pr, gs_list)
mstate = zz_state(d)
update_bound(bb, my_ll, prior, gs_list, mstate);
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:12

# %% [markdown]
# #### Define mbsampler + block Gibbs sampler list:

# %%
adapt_speed = "by_var"
L = 1
my_zz_sampler = zz_sampler(0, gs_list, bb, L, adapt_speed)
hyper_sampler = block_gibbs_sampler(2e4)
blocksampler = Array{msampler}(2)
blocksampler[1] = my_zz_sampler
blocksampler[2] = hyper_sampler;

# %% [markdown]
# #### Run sampler:

# %%
ZZ_block_sample(my_model, outp, blocksampler, mstate);
# Out:
# 10% attempts in 0.13 mins
# 20% attempts in 0.23 mins
# 30% attempts in 0.33 mins
# Trimmed after 10000 bouncing attempts
# 40% attempts in 0.44 mins
# 50% attempts in 0.54 mins
# 60% attempts in 0.65 mins
# 70% attempts in 0.75 mins
# 80% attempts in 0.86 mins
# 90% attempts in 0.96 mins
# 100% attempts in 1.07 mins

# %%
print(maximum(abs.(outp.opf.xi_mu - mstate.mu)), "\n")
print(maximum(abs.(outp.opf.xi_m2 - mstate.m2)))
# Out:
# 1.0871356018513154
# 7.1272134687557696

# %% [markdown]
# * Number of bounces:

# %%
zz_bounces = sum(mstate.n_bounces)
hyp_bounces = outp.opf.tot_bounces-sum(mstate.n_bounces)
@printf("ZZ total bounces: %i, hyper bounces: %i", zz_bounces, hyp_bounces)
# Out:
# ZZ total bounces: 339985, hyper bounces: 39957

# %%
size(outp.opf.xi_skeleton,2)/outp.opt.max_attempts
# Out:
# 0.01176715

# %%
post_mean_gzz = outp.opf.xi_mu
# post_median_gzz = median(xi_samples,2);

# %%
fig = figure(figsize=(12,3))
plot(sort(abs.(ξ_true.nzval), rev=true), "o-", markersize=3, label="true signal")
plot(sort(vec(abs.(post_mean_gzz)), rev=true)[1:150], "o-", markersize=3, label="posterior mean")
# plot(sort(vec(abs.(post_median_gzz)), rev=true)[1:50], "o-", markersize=3, label="posterior median")
grid(true)
title("Absolute values of sorted posterior means for GZZ sampler")
legend(ncol=3)
xlabel("Parameter index")
ylabel("Value")
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x300 with 1 Axes>)
# PyObject Text(24.000000000000007, 0.5, 'Value')

# %% [raw]
# maximum(abs.(mean(xi_samples,2) - mstate.mu))

# %%
fig = figure(figsize=(12,3))
plot(abs.(ξ_true.nzval), "o-", markersize=3, label="true signal")
plot(vec(abs.(post_mean_gzz))[ξ_true.nzind], "o-", markersize=3, label="posterior mean")
grid(true)
title("Absolute values of posterior means for GZZ sampler")
legend(ncol=3)
xlabel("Parameter index")
ylabel("Value");
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x300 with 1 Axes>)

# %% [markdown]
# ### Credible intervals:

# %% [raw]
# outp.opf.bt_skeleton[1,end]

# %% [raw]
# h = 0.2
# B = Int(round(outp.opf.bt_skeleton[1,end]/h))
# ESS = compute_ESS(outp.opf, B)
# print("Mean ESS = ", mean(ESS))

# %%
xi_sd = sqrt.(outp.opf.xi_m2 - outp.opf.xi_mu.^2)
ci = zeros(d,2)
ci[:,1] = outp.opf.xi_mu-3*xi_sd
ci[:,2] = outp.opf.xi_mu+3*xi_sd;

# %%
fig = figure(figsize=(12,3))
@showprogress for i in 1:d
    plot([i,i], ci[i,:], "b-", lw=0.5)
end
plot(1:d, outp.opf.xi_mu, "ro", markersize=2, label="posterior mean");
plot(1:d, ξ_true, "gx", markersize=2, label="true parameter")
grid(true)
xlim(-50,d+50)
xlabel("Component index")
ylabel("Value")
title("Confidence intervals for signals")
legend(ncol=2,bbox_to_anchor=(0.65, 1))
savefig("plots/CId10K.pdf", format="pdf", dpi=10000, bbox_inches="tight")
# Out:
# Progress: 100%|█████████████████████████████████████████|  ETA: 0:00:00
# PyPlot.Figure(PyObject <Figure size 1200x300 with 1 Axes>)
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:31

# %%
save("/home/postdoc/dsen/Desktop/GZZ_data/data/opf_d10K.jld", "opf", outp.opf, "X", X, "y", y, "xi_true", ξ_true)

# %%
X = load("/home/postdoc/dsen/Desktop/GZZ_data/data/opf_d10K.jld", "X");

# %%
xxt = X*X';

# %%
X
# Out:
# 10000×12000 SparseMatrixCSC{Float64,Int64} with 12006487 stored entries:
#   [1    ,     1]  =  1.0
#   [3    ,     1]  =  0.203041
#   [23   ,     1]  =  1.70964
#   [36   ,     1]  =  1.0435
#   [46   ,     1]  =  -1.524
#   [48   ,     1]  =  -0.359417
#   [55   ,     1]  =  -0.677926
#   [62   ,     1]  =  -0.133739
#   [63   ,     1]  =  1.61836
#   [109  ,     1]  =  -1.67409
#   ⋮
#   [9809 , 12000]  =  -0.421039
#   [9810 , 12000]  =  -0.0746185
#   [9864 , 12000]  =  0.64756
#   [9881 , 12000]  =  1.47406
#   [9882 , 12000]  =  0.565461
#   [9955 , 12000]  =  -0.376546
#   [9958 , 12000]  =  -2.65198
#   [9967 , 12000]  =  0.18772
#   [9968 , 12000]  =  -2.12941
#   [9972 , 12000]  =  -1.27934
#   [9987 , 12000]  =  -1.70771

# %%
12006487/(10_000*12_000)
# Out:
# 0.10005405833333333

# %%
sum(xxt .== 0.)
# Out:
# 0

# %%
xxt
# Out:
# 10000×10000 SparseMatrixCSC{Float64,Int64} with 100000000 stored entries:
#   [1    ,     1]  =  12000.0
#   [2    ,     1]  =  -14.091
#   [3    ,     1]  =  -57.4135
#   [4    ,     1]  =  -12.3292
#   [5    ,     1]  =  -7.43987
#   [6    ,     1]  =  10.5899
#   [7    ,     1]  =  0.0196125
#   [8    ,     1]  =  -62.913
#   [9    ,     1]  =  6.40147
#   [10   ,     1]  =  -3.15088
#   ⋮
#   [9990 , 10000]  =  -3.70255
#   [9991 , 10000]  =  8.2479
#   [9992 , 10000]  =  3.5322
#   [9993 , 10000]  =  -9.43351
#   [9994 , 10000]  =  9.73751
#   [9995 , 10000]  =  -7.74204
#   [9996 , 10000]  =  -10.6284
#   [9997 , 10000]  =  -8.15439
#   [9998 , 10000]  =  -9.64979
#   [9999 , 10000]  =  4.94621
#   [10000, 10000]  =  1207.28
