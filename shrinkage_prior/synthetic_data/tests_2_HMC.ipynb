# %%
using Distributions, TimeIt, ProgressMeter, PyPlot, JLD
include("/home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl")
include("temp.jl")
# Out:
# run_sampler (generic function with 4 methods)

# %%
X, y = load("shrinkage_data_2.jld", "X", "y")
d, Nobs = size(X)
σ02 = 1
my_pr = SS_prior(d, σ02)
my_ll = ll_logistic_sp(X,y)
my_model = model(my_ll, my_pr);

# %% [markdown]
# ### HMC:

# %% [markdown]
# ### Tune HMC:

# %%
ξ0 = randn(d)
Total_time = 10
T = 250
Metropolise = false
Print = false
n_leapfrog_list = 20*(1:5)
prior = SS_prior(d, σ02);

# %%
xi_samples_hmc, hyper_samples_hmc, acc = 
zeros(d,T+1,length(n_leapfrog_list)), zeros(hyperparam_size(prior),T+1,length(n_leapfrog_list)), 
zeros(length(n_leapfrog_list));

# %%
for (i,n_leapfrog) in enumerate(reverse(n_leapfrog_list))
    start = time()
    prior = SS_prior(d, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    stepsize = Total_time/n_leapfrog
    xi_samples_hmc[:,:,i], hyper_samples_hmc[:,:,i], acc[i] = 
    GibbsHMC(my_model, ξ0, stepsize, n_leapfrog, T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
end
# Out:
# HMC acceptance = 100.0 percent; n_leapfrog = 100 in 6.81 mins
# HMC acceptance = 100.0 percent; n_leapfrog = 80 in 6.65 mins
# HMC acceptance = 100.0 percent; n_leapfrog = 60 in 4.85 mins
# ArgumentError: InverseGamma: the condition α > zero(α) && θ > zero(θ) is not satisfied.
#
# Stacktrace:
#  [1] macro expansion at /home/postdoc/dsen/.julia/v0.6/Distributions/src/utils.jl:6 [inlined]
#  [2] Distributions.InverseGamma{Float64}(::Float64, ::Float64) at /home/postdoc/dsen/.julia/v0.6/Distributions/src/univariate/continuous/inversegamma.jl:33
#  [3] (::##505#511{SS_prior,Array{Float64,1}})(::Int64) at ./<missing>:0
#  [4] collect(::Base.Generator{UnitRange{Int64},##505#511{SS_prior,Array{Float64,1}}}) at ./array.jl:470
#  [5] block_Gibbs_update_hyperparams(::SS_prior, ::Array{Float64,1}) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/priors.jl:153
#  [6] GibbsHMC(::model, ::Array{Float64,1}, ::Float64, ::Int64, ::Int64, ::Bool, ::Bool) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl:632
#  [7] macro expansion at ./In[6]:7 [inlined]
#  [8] anonymous at ./<missing>:?
#  [9] include_string(::String, ::String) at ./loading.jl:522

# %%
Metropolise = true 
Print = false

stepsize = Total_time/50
total_times = 2*stepsize*(5:15)
n_leapfrog_steps = 5*(1:10)

for total_time in total_times
    print("Total time = ", round(total_time,2), "\n")
    for n_leapfrog in n_leapfrog_steps
        start = time()
        prior = SS_prior(d, σ02)
        my_ll = ll_logistic_sp(X,y)
        my_model = model(my_ll, prior)
        a, b, c = 
        GibbsHMC(my_model, ξ0, total_time/n_leapfrog, n_leapfrog, 500, Metropolise, Print)
        print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
    end
end
# Out:
# Total time = 2.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.42 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.75 mins
# HMC acceptance = 19.0 percent; n_leapfrog = 15 in 1.09 mins
# HMC acceptance = 71.0 percent; n_leapfrog = 20 in 1.43 mins
# HMC acceptance = 83.8 percent; n_leapfrog = 25 in 1.78 mins
# HMC acceptance = 91.4 percent; n_leapfrog = 30 in 2.11 mins
# HMC acceptance = 92.2 percent; n_leapfrog = 35 in 2.45 mins
# HMC acceptance = 94.2 percent; n_leapfrog = 40 in 2.79 mins
# HMC acceptance = 95.4 percent; n_leapfrog = 45 in 3.13 mins
# HMC acceptance = 95.8 percent; n_leapfrog = 50 in 3.43 mins
# Total time = 2.4
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.41 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.74 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 15 in 1.08 mins
# HMC acceptance = 58.0 percent; n_leapfrog = 20 in 1.42 mins
# HMC acceptance = 75.6 percent; n_leapfrog = 25 in 1.74 mins
# HMC acceptance = 85.6 percent; n_leapfrog = 30 in 2.08 mins
# HMC acceptance = 90.8 percent; n_leapfrog = 35 in 2.42 mins
# HMC acceptance = 90.6 percent; n_leapfrog = 40 in 2.77 mins
# HMC acceptance = 93.6 percent; n_leapfrog = 45 in 3.09 mins
# HMC acceptance = 93.0 percent; n_leapfrog = 50 in 3.43 mins
# Total time = 2.8
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.41 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.74 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 15 in 1.08 mins
# HMC acceptance = 2.4 percent; n_leapfrog = 20 in 1.41 mins
# HMC acceptance = 64.0 percent; n_leapfrog = 25 in 1.75 mins
# HMC acceptance = 73.2 percent; n_leapfrog = 30 in 2.08 mins
# HMC acceptance = 82.4 percent; n_leapfrog = 35 in 2.43 mins
# HMC acceptance = 88.8 percent; n_leapfrog = 40 in 2.76 mins
# HMC acceptance = 91.2 percent; n_leapfrog = 45 in 3.09 mins
# HMC acceptance = 92.6 percent; n_leapfrog = 50 in 3.43 mins
# Total time = 3.2
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.41 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.74 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.07 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 20 in 1.41 mins
# HMC acceptance = 46.6 percent; n_leapfrog = 25 in 1.76 mins
# HMC acceptance = 64.4 percent; n_leapfrog = 30 in 2.08 mins
# HMC acceptance = 79.0 percent; n_leapfrog = 35 in 2.43 mins
# HMC acceptance = 82.0 percent; n_leapfrog = 40 in 2.76 mins
# HMC acceptance = 88.4 percent; n_leapfrog = 45 in 3.11 mins
# HMC acceptance = 92.2 percent; n_leapfrog = 50 in 3.49 mins
# Total time = 3.6
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.43 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.77 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.1 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 20 in 1.4 mins
# HMC acceptance = 0.8 percent; n_leapfrog = 25 in 1.74 mins
# HMC acceptance = 56.2 percent; n_leapfrog = 30 in 2.08 mins
# HMC acceptance = 64.6 percent; n_leapfrog = 35 in 2.42 mins
# HMC acceptance = 78.8 percent; n_leapfrog = 40 in 2.76 mins
# HMC acceptance = 84.4 percent; n_leapfrog = 45 in 3.11 mins
# HMC acceptance = 87.2 percent; n_leapfrog = 50 in 3.43 mins
# Total time = 4.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.41 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.74 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.07 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.4 mins
# HMC acceptance = 0.8 percent; n_leapfrog = 25 in 1.74 mins
# HMC acceptance = 15.4 percent; n_leapfrog = 30 in 2.08 mins
# HMC acceptance = 65.0 percent; n_leapfrog = 35 in 2.42 mins
# HMC acceptance = 73.4 percent; n_leapfrog = 40 in 2.78 mins
# HMC acceptance = 79.4 percent; n_leapfrog = 45 in 3.1 mins
# HMC acceptance = 82.2 percent; n_leapfrog = 50 in 3.44 mins
# Total time = 4.4
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.41 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.74 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.07 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.41 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.74 mins
# HMC acceptance = 0.8 percent; n_leapfrog = 30 in 2.08 mins
# HMC acceptance = 48.0 percent; n_leapfrog = 35 in 2.43 mins
# HMC acceptance = 63.4 percent; n_leapfrog = 40 in 2.75 mins
# HMC acceptance = 74.0 percent; n_leapfrog = 45 in 3.1 mins
# HMC acceptance = 81.6 percent; n_leapfrog = 50 in 3.43 mins
# Total time = 4.8
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.41 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.74 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.07 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.43 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.8 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 30 in 2.11 mins
# HMC acceptance = 2.6 percent; n_leapfrog = 35 in 2.45 mins
# HMC acceptance = 57.8 percent; n_leapfrog = 40 in 2.79 mins
# HMC acceptance = 64.0 percent; n_leapfrog = 45 in 3.13 mins
# HMC acceptance = 74.0 percent; n_leapfrog = 50 in 3.48 mins
# Total time = 5.2
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.43 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.77 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.1 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.45 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.76 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 30 in 2.1 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 35 in 2.51 mins
# HMC acceptance = 35.6 percent; n_leapfrog = 40 in 2.91 mins
# HMC acceptance = 58.2 percent; n_leapfrog = 45 in 3.19 mins
# HMC acceptance = 66.2 percent; n_leapfrog = 50 in 3.51 mins
# Total time = 5.6
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.42 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.75 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.09 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.43 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.75 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 2.08 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 35 in 2.41 mins
# HMC acceptance = 1.0 percent; n_leapfrog = 40 in 2.77 mins
# HMC acceptance = 50.0 percent; n_leapfrog = 45 in 3.09 mins
# HMC acceptance = 63.6 percent; n_leapfrog = 50 in 3.43 mins
# Total time = 6.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.41 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.74 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.07 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.41 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.75 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 2.08 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 35 in 2.43 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 40 in 2.8 mins
# HMC acceptance = 16.8 percent; n_leapfrog = 45 in 3.09 mins
# HMC acceptance = 54.6 percent; n_leapfrog = 50 in 3.47 mins

# %%
total_times_optimal = [2.0, 2.4, 2.8, 3.2, 3.6, 4.0, 4.4, 4.8, 5.2, 5.6]
n_leapfrog_optimal =  [20 , 20 , 25 , 30 , 35 , 35 , 40 , 45 , 50 , 50]
T = 5000
Metropolise = true
Print = false

for (i,total_time) in enumerate(total_times_optimal) 
    start = time()
    prior = SS_prior(d, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    xi_samples_hmc, hyper_samples_hmc, acc =
    GibbsHMC(my_model, ξ0, total_time/n_leapfrog_optimal[i], n_leapfrog_optimal[i], T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog_optimal[i], " in ", round((time()-start)/60,2), " mins \n")
    filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/GibbsHMC:d:"*string(d)*"-Nobs:"*string(Nobs)*
                "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog_optimal[i])*".jld"
    save(filename, "xi_samples", xi_samples_hmc, "hyper_samples", hyper_samples_hmc, "acc", acc)
    xi_samples_hmc, hyper_samples_hmc, acc = [], [], []
    gc()
end
# Out:
# HMC acceptance = 71.84 percent; n_leapfrog = 20 in 14.4 mins
# HMC acceptance = 59.6 percent; n_leapfrog = 20 in 14.36 mins
# HMC acceptance = 64.06 percent; n_leapfrog = 25 in 17.78 mins
# HMC acceptance = 63.28 percent; n_leapfrog = 30 in 21.17 mins
# HMC acceptance = 65.6 percent; n_leapfrog = 35 in 24.56 mins
# HMC acceptance = 60.9 percent; n_leapfrog = 35 in 24.57 mins
# HMC acceptance = 62.52 percent; n_leapfrog = 40 in 27.98 mins
# HMC acceptance = 65.02 percent; n_leapfrog = 45 in 31.38 mins
# HMC acceptance = 69.04 percent; n_leapfrog = 50 in 34.83 mins
# HMC acceptance = 62.14 percent; n_leapfrog = 50 in 34.63 mins

# %%
maxlag_hmc = 50
fig = figure(figsize=(12,4))
acfs_hmc = zeros(length(total_times_optimal),size(xi_samples_hmc,1),maxlag_hmc)

for i in 1:2 
    for j in 1:5
        k = 5*(i-1)+j
        total_time, n_leapfrog = total_times_optimal[k], n_leapfrog_optimal[k]
        filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/GibbsHMC:d:"*string(d)*"-Nobs:"*string(Nobs)*
                   "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog)*".jld"
        xi_samples_hmc = load(filename, "xi_samples")

        subplot(2,5,k)
        for dim in 1:size(xi_samples_hmc,1) 
            a = acf(xi_samples_hmc[dim,:], maxlag_hmc)
            plot(a)
            acfs_hmc[k,dim,:] = a
        end
        grid(true)  
        title("Total time:"*string(total_time)*", \n n_leapfrog:"*string(n_leapfrog), fontsize=10)
        xi_samples_hmc = []
        gc()
        if i == 2 xlabel("Lag") end
        if i == 1 xticks(alpha=0) end
        if j == 1 ylabel("ACF") end
        subplots_adjust(hspace=0.4)
    end
end
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x400 with 10 Axes>)

# %%
mb_size = 1
max_attempts = 5*10^6
lambda = 2e1

fig = figure("pyplot_barplot",figsize=(5,3))
n_samples = 10^4
maxlag_gzz = 500
acfs_gzz = zeros(d,maxlag_gzz)
discard = 0
filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/lambda:"*string(lambda)*
            "-d:"*string(d)*"-Nobs:"*string(Nobs)*"-mb_size:"*string(mb_size)*".jld"
xt_skel, bt_skel = load(filename, "xt_skeleton", "bt_skeleton")
xi_samples_gzz = extract_samples(xt_skel[:,discard+1:end], 
                             bt_skel[:,discard+1:end], 
                            (bt_skel[end]-bt_skel[discard+1])/n_samples,
                            "linear")[:,1:end-1]
iacts_gzz = zeros(size(xi_samples_gzz,1))
for dim in 1:size(xi_samples_gzz,1)
    a = acf(xi_samples_gzz[dim,:],maxlag_gzz)
    plot(a)
    acfs_gzz[dim,:] = a
end
title("ACFs for GZZ")
xlabel("Lag")
ylabel("ACF")
grid(true)
xt_skel, bt_skel, xi_samples = [], [], []
gc()
# Out:
# PyPlot.Figure(PyObject <Figure size 500x300 with 1 Axes>)

# %%
hmc_mixing = T./maximum(sum(acfs_hmc[:,:,1:20],3),2)
hmc_cost = T*n_leapfrog_optimal*Nobs;

# %%
gzz_mixing = n_samples/maximum(sum(acfs_gzz[:,1:100],2))
gzz_cost = max_attempts*mb_size;

# %%
(gzz_mixing/gzz_cost)./(hmc_mixing./hmc_cost)
# Out:
# 10×1×1 Array{Float64,3}:
# [:, :, 1] =
#   7.15625
#  10.0487
#   6.72817
#   3.34612
#   6.34688
#   6.17175
#   7.07985
#   8.17075
#  10.5114
#   9.66999
