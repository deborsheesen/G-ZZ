# %%
using Distributions, TimeIt, ProgressMeter, PyPlot, JLD
include("temp.jl")
# Out:
# run_sampler (generic function with 4 methods)

# %%
X, y, ξ_true = load("data.jld", "X", "y", "xi_true")
d, Nobs = size(X)
σ02 = 1
my_pr = SS_prior(d, σ02)
my_ll = ll_logistic_sp(X,y)
my_model = model(my_ll, my_pr);

# %%
# Sub-sampling without control variates and with weights:
mb_size = 10
max_attempts = 10^7
lambda_list = logspace(0,3,10)
Print = false
# Out:
# false

# %%
start_overall = time()
for lambda in lambda_list 
    start = time()
    run_sampler(my_model, lambda, max_attempts, mb_size, Print) 
    print("Sampling for lambda = ", lambda, " in ", round((time()-start)/60,1), " mins \n")
end
print("Overall in ", round((time()-start_overall)/60,1), " mins")
# Out:
# Sampling for lambda = 1.0 in 113.0 mins
# Sampling for lambda = 2.154434690031884 in 109.8 mins
# Sampling for lambda = 4.641588833612778 in 111.4 mins
# Sampling for lambda = 10.0 in 108.4 mins
# Sampling for lambda = 21.544346900318832 in 102.0 mins
# Sampling for lambda = 46.4158883361278 in 109.9 mins
# Sampling for lambda = 100.0 in 125.3 mins
# Sampling for lambda = 215.44346900318845 in 131.2 mins
# Sampling for lambda = 464.15888336127773 in 146.5 mins
# Sampling for lambda = 1000.0 in 134.8 mins
# Overall in 1192.3 mins

# %%
fig = figure("pyplot_barplot",figsize=(12,4))
n_samples = 10^4
maxlag = 1000
discard = 0
iacts = zeros(10)
for j in 1:2 
    for i in 1:5
        k = (j-1)*5+i
        filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/lambda:"*
        string(lambda_list[k])*"-d:"*string(d)*"-Nobs:"*
        string(Nobs)*"-mb_size:"*string(mb_size)*".jld"
        xt_skel, bt_skel = load(filename, "xt_skeleton", "bt_skeleton")
        xi_samples = extract_samples(xt_skel[:,discard+1:end], 
                                     bt_skel[:,discard+1:end], 
                                    (bt_skel[end]-bt_skel[discard+1])/n_samples,
                                    "linear")[:,1:end-1];
        subplot(2,5,k)
        for dim in 1:size(xi_samples,1)
            plot(acf(xi_samples[dim,:],maxlag))
            title("lambda = "*string(round(lambda_list[k],3)), fontsize=10)
            grid(true)
        end
        iacts[k] = maximum([sum(acf(xi_samples[dim,:],maxlag)) for dim in 1:size(xi_samples,1)])
        print("lambda = "*string(round(lambda_list[k],2)), " slowest mixing = ", 
                round(iacts[k],1), "\n")
        xt_skel, bt_skel, xi_samples = [], [], []
        gc()
    end
end
subplots_adjust(hspace=0.4)
# Out:
# lambda = 1.0 slowest mixing = 372.5
# lambda = 2.15 slowest mixing = 703.1
# lambda = 4.64 slowest mixing = 827.8
# lambda = 10.0 slowest mixing = 824.9
# lambda = 21.54 slowest mixing = 836.7
# lambda = 46.42 slowest mixing = 456.1
# lambda = 100.0 slowest mixing = 666.7
# lambda = 215.44 slowest mixing = 800.5
# lambda = 464.16 slowest mixing = 667.3
# PyPlot.Figure(PyObject <Figure size 1200x400 with 10 Axes>)
# lambda = 1000.0 slowest mixing = 764.9
