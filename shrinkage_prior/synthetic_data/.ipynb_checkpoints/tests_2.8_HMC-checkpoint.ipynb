# %%
using Distributions, TimeIt, ProgressMeter, PyPlot, JLD
include("/home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl")
include("temp.jl")
# Out:
# run_sampler (generic function with 4 methods)

# %%
X, y = load("shrinkage_data_2.8.jld", "X", "y")
d, Nobs = size(X)
σ02 = 1
my_pr = SS_prior(d, σ02)
my_ll = ll_logistic_sp(X,y)
my_model = model(my_ll, my_pr)
print("d = ",  d, ", N = ", Nobs)
# Out:
# d = 101, N = 800

# %% [markdown]
# ### HMC:

# %% [markdown]
# ### Tune HMC:

# %%
ξ0 = randn(d)
Total_time = 10
T = 250
Metropolise = false
Print = false
n_leapfrog_list = 20*(1:5)
prior = SS_prior(d, σ02);

# %%
xi_samples_hmc, hyper_samples_hmc, acc = 
zeros(d,T+1,length(n_leapfrog_list)), zeros(hyperparam_size(prior),T+1,length(n_leapfrog_list)), 
zeros(length(n_leapfrog_list));

# %%
for (i,n_leapfrog) in enumerate(reverse(n_leapfrog_list))
    start = time()
    prior = SS_prior(d, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    stepsize = Total_time/n_leapfrog
    xi_samples_hmc[:,:,i], hyper_samples_hmc[:,:,i], acc[i] = 
    GibbsHMC(my_model, ξ0, stepsize, n_leapfrog, T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
end
# Out:
# HMC acceptance = 100.0 percent; n_leapfrog = 100 in 3.91 mins
# HMC acceptance = 100.0 percent; n_leapfrog = 80 in 3.14 mins
# HMC acceptance = 100.0 percent; n_leapfrog = 60 in 2.36 mins
# ArgumentError: InverseGamma: the condition α > zero(α) && θ > zero(θ) is not satisfied.
#
# Stacktrace:
#  [1] macro expansion at /home/postdoc/dsen/.julia/v0.6/Distributions/src/utils.jl:6 [inlined]
#  [2] Distributions.InverseGamma{Float64}(::Float64, ::Float64) at /home/postdoc/dsen/.julia/v0.6/Distributions/src/univariate/continuous/inversegamma.jl:33
#  [3] (::##505#511{SS_prior,Array{Float64,1}})(::Int64) at ./<missing>:0
#  [4] collect(::Base.Generator{UnitRange{Int64},##505#511{SS_prior,Array{Float64,1}}}) at ./array.jl:470
#  [5] block_Gibbs_update_hyperparams(::SS_prior, ::Array{Float64,1}) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/priors.jl:152
#  [6] GibbsHMC(::model, ::Array{Float64,1}, ::Float64, ::Int64, ::Int64, ::Bool, ::Bool) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl:634
#  [7] macro expansion at ./In[5]:7 [inlined]
#  [8] anonymous at ./<missing>:?
#  [9] include_string(::String, ::String) at ./loading.jl:522

# %%
Metropolise = true 
Print = false

stepsize = Total_time/50
total_times = 2.0*stepsize*(5:15)
n_leapfrog_steps = 5*(1:10)

for total_time in total_times
    print("Total time = ", round(total_time,2), "\n")
    for n_leapfrog in n_leapfrog_steps
        start = time()
        prior = SS_prior(d, σ02)
        my_ll = ll_logistic_sp(X,y)
        my_model = model(my_ll, prior)
        a, b, c = 
        GibbsHMC(my_model, ξ0, total_time/n_leapfrog, n_leapfrog, 500, Metropolise, Print)
        print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
    end
end
# Out:
# Total time = 2.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.47 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 10 in 0.89 mins
# HMC acceptance = 58.2 percent; n_leapfrog = 15 in 1.29 mins
# HMC acceptance = 75.8 percent; n_leapfrog = 20 in 1.72 mins
# HMC acceptance = 87.4 percent; n_leapfrog = 25 in 2.19 mins
# HMC acceptance = 91.6 percent; n_leapfrog = 30 in 2.49 mins
# HMC acceptance = 91.0 percent; n_leapfrog = 35 in 2.83 mins
# HMC acceptance = 94.2 percent; n_leapfrog = 40 in 3.15 mins
# HMC acceptance = 96.4 percent; n_leapfrog = 45 in 3.64 mins
# HMC acceptance = 97.6 percent; n_leapfrog = 50 in 3.98 mins
# Total time = 2.4
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.46 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.85 mins
# HMC acceptance = 3.2 percent; n_leapfrog = 15 in 1.23 mins
# HMC acceptance = 62.0 percent; n_leapfrog = 20 in 1.6 mins
# HMC acceptance = 80.0 percent; n_leapfrog = 25 in 2.04 mins
# HMC acceptance = 86.2 percent; n_leapfrog = 30 in 2.5 mins
# HMC acceptance = 88.8 percent; n_leapfrog = 35 in 2.81 mins
# HMC acceptance = 91.2 percent; n_leapfrog = 40 in 3.17 mins
# HMC acceptance = 95.2 percent; n_leapfrog = 45 in 3.54 mins
# HMC acceptance = 96.2 percent; n_leapfrog = 50 in 3.93 mins
# Total time = 2.8
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.48 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.86 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 15 in 1.26 mins
# HMC acceptance = 44.6 percent; n_leapfrog = 20 in 1.64 mins
# HMC acceptance = 76.0 percent; n_leapfrog = 25 in 2.04 mins
# HMC acceptance = 77.4 percent; n_leapfrog = 30 in 2.41 mins
# HMC acceptance = 89.0 percent; n_leapfrog = 35 in 2.84 mins
# HMC acceptance = 89.4 percent; n_leapfrog = 40 in 3.24 mins
# HMC acceptance = 92.2 percent; n_leapfrog = 45 in 3.59 mins
# HMC acceptance = 91.6 percent; n_leapfrog = 50 in 3.92 mins
# Total time = 3.2
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.51 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.87 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.22 mins
# HMC acceptance = 3.4 percent; n_leapfrog = 20 in 1.62 mins
# HMC acceptance = 60.8 percent; n_leapfrog = 25 in 1.97 mins
# HMC acceptance = 71.0 percent; n_leapfrog = 30 in 2.37 mins
# HMC acceptance = 85.2 percent; n_leapfrog = 35 in 2.87 mins
# HMC acceptance = 85.4 percent; n_leapfrog = 40 in 3.3 mins
# HMC acceptance = 86.6 percent; n_leapfrog = 45 in 3.6 mins
# HMC acceptance = 89.0 percent; n_leapfrog = 50 in 4.04 mins
# Total time = 3.6
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.46 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.84 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.22 mins
# HMC acceptance = 1.0 percent; n_leapfrog = 20 in 1.63 mins
# HMC acceptance = 45.8 percent; n_leapfrog = 25 in 1.99 mins
# HMC acceptance = 64.0 percent; n_leapfrog = 30 in 2.37 mins
# HMC acceptance = 80.4 percent; n_leapfrog = 35 in 2.76 mins
# HMC acceptance = 79.4 percent; n_leapfrog = 40 in 3.14 mins
# HMC acceptance = 85.2 percent; n_leapfrog = 45 in 3.52 mins
# HMC acceptance = 89.0 percent; n_leapfrog = 50 in 3.84 mins
# Total time = 4.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.46 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.84 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.24 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 20 in 1.6 mins
# HMC acceptance = 2.8 percent; n_leapfrog = 25 in 1.96 mins
# HMC acceptance = 55.4 percent; n_leapfrog = 30 in 2.34 mins
# HMC acceptance = 69.4 percent; n_leapfrog = 35 in 2.74 mins
# HMC acceptance = 76.6 percent; n_leapfrog = 40 in 3.27 mins
# HMC acceptance = 81.6 percent; n_leapfrog = 45 in 3.66 mins
# HMC acceptance = 88.0 percent; n_leapfrog = 50 in 3.85 mins
# Total time = 4.4
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.46 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.83 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.21 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.67 mins
# HMC acceptance = 1.2 percent; n_leapfrog = 25 in 2.01 mins
# HMC acceptance = 39.4 percent; n_leapfrog = 30 in 2.36 mins
# HMC acceptance = 63.4 percent; n_leapfrog = 35 in 2.73 mins
# HMC acceptance = 73.6 percent; n_leapfrog = 40 in 3.23 mins
# HMC acceptance = 79.4 percent; n_leapfrog = 45 in 3.56 mins
# HMC acceptance = 82.2 percent; n_leapfrog = 50 in 3.9 mins
# Total time = 4.8
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.46 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.87 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.26 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.74 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 25 in 2.06 mins
# HMC acceptance = 1.4 percent; n_leapfrog = 30 in 2.53 mins
# HMC acceptance = 53.4 percent; n_leapfrog = 35 in 2.81 mins
# HMC acceptance = 65.4 percent; n_leapfrog = 40 in 3.18 mins
# HMC acceptance = 77.0 percent; n_leapfrog = 45 in 3.59 mins
# HMC acceptance = 79.8 percent; n_leapfrog = 50 in 3.82 mins
# Total time = 5.2
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.45 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.83 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.2 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.58 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.95 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 30 in 2.34 mins
# HMC acceptance = 39.0 percent; n_leapfrog = 35 in 2.73 mins
# HMC acceptance = 60.4 percent; n_leapfrog = 40 in 3.07 mins
# HMC acceptance = 72.0 percent; n_leapfrog = 45 in 3.45 mins
# HMC acceptance = 76.8 percent; n_leapfrog = 50 in 3.83 mins
# Total time = 5.6
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.45 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.82 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.21 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.59 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.95 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 30 in 2.32 mins
# HMC acceptance = 2.2 percent; n_leapfrog = 35 in 2.71 mins
# HMC acceptance = 47.4 percent; n_leapfrog = 40 in 3.29 mins
# HMC acceptance = 65.0 percent; n_leapfrog = 45 in 3.59 mins
# HMC acceptance = 69.2 percent; n_leapfrog = 50 in 3.94 mins
# Total time = 6.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.46 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.83 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.2 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.66 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.99 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 2.33 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 35 in 2.7 mins
# HMC acceptance = 35.0 percent; n_leapfrog = 40 in 2.96 mins
# HMC acceptance = 55.6 percent; n_leapfrog = 45 in 3.27 mins
# HMC acceptance = 67.6 percent; n_leapfrog = 50 in 3.6 mins

# %%
total_times_optimal = [2.0, 2.4, 2.8, 3.2, 3.6, 4.0, 4.4, 4.8, 5.2, 5.6, 6.0]
n_leapfrog_optimal =  [16 , 21 , 23 , 27 , 30 , 34 , 36 , 40 , 42 , 45 , 49 ]
T = 5000
Metropolise = true
Print = false

for (i,total_time) in enumerate(total_times_optimal) 
    start = time()
    prior = SS_prior(d, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    xi_samples_hmc, hyper_samples_hmc, acc =
    GibbsHMC(my_model, ξ0, total_time/n_leapfrog_optimal[i], n_leapfrog_optimal[i], T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog_optimal[i], " in ", round((time()-start)/60,2), " mins \n")
    filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/GibbsHMC:d:"*string(d)*"-Nobs:"*string(Nobs)*
                "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog_optimal[i])*".jld"
    save(filename, "xi_samples", xi_samples_hmc, "hyper_samples", hyper_samples_hmc, "acc", acc)
    xi_samples_hmc, hyper_samples_hmc, acc = [], [], []
    gc()
end
# Out:
# HMC acceptance = 57.38 percent; n_leapfrog = 16 in 13.34 mins
# HMC acceptance = 74.08 percent; n_leapfrog = 21 in 16.98 mins
# HMC acceptance = 66.28 percent; n_leapfrog = 23 in 18.3 mins
# HMC acceptance = 68.46 percent; n_leapfrog = 27 in 21.34 mins
# HMC acceptance = 67.34 percent; n_leapfrog = 30 in 23.65 mins
# HMC acceptance = 65.4 percent; n_leapfrog = 34 in 26.75 mins
# HMC acceptance = 65.18 percent; n_leapfrog = 36 in 28.24 mins
# HMC acceptance = 64.58 percent; n_leapfrog = 40 in 29.66 mins
# HMC acceptance = 63.24 percent; n_leapfrog = 42 in 31.05 mins
# HMC acceptance = 61.48 percent; n_leapfrog = 45 in 33.19 mins
# HMC acceptance = 65.42 percent; n_leapfrog = 49 in 35.92 mins

# %%
total_times_optimal = [2.0, 2.4, 2.8, 3.2, 3.6, 4.0, 4.4, 4.8, 5.2, 5.6, 6.0]
n_leapfrog_optimal =  [16 , 21 , 23 , 27 , 30 , 34 , 36 , 40 , 42 , 45 , 49 ]
T = 5000
# Out:
# 5000

# %%
maxlag_hmc = 50
fig = figure(figsize=(12,4))
acfs_hmc = zeros(length(total_times_optimal),d,maxlag_hmc)

for i in 1:2 
    for j in 1:5
        k = 5*(i-1)+j
        total_time, n_leapfrog = total_times_optimal[k+1], n_leapfrog_optimal[k+1]
        filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/GibbsHMC:d:"*string(d)*"-Nobs:"*string(Nobs)*
                   "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog)*".jld"
        xi_samples_hmc = load(filename, "xi_samples")

        .0
        subplot(2,5,k)
        for dim in 1:size(xi_samples_hmc,1) 
            a = acf(xi_samples_hmc[dim,:], maxlag_hmc)
            plot(a)
            acfs_hmc[k,dim,:] = a
        end
        grid(true)  
        title("Total time:"*string(total_time)*", \n n_leapfrog:"*string(n_leapfrog), fontsize=10)
        xi_samples_hmc = []
        gc()
        if i == 2 xlabel("Lag") end
        if i == 1 xticks(alpha=0) end
        if j == 1 ylabel("ACF") end
        subplots_adjust(hspace=0.4)
    end
end
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x400 with 10 Axes>)

# %%
maxlag_hmc_list = [50, 30, 20, 20, 10, 20, 15, 20, 20, 20]
hmc_mixing = zeros(length(total_times_optimal))
for i in 1:10
    hmc_mixing[i] = T/maximum(sum(acfs_hmc[i,:,1:maxlag_hmc_list[i]],2))
end
hmc_cost = T*n_leapfrog_optimal*Nobs;

# %%
mb_size = 1
max_attempts = 10^7
lambda = 2e1

fig = figure("pyplot_barplot",figsize=(5,3))
n_samples = 10^4
maxlag_gzz = 500
acfs_gzz = zeros(d,maxlag_gzz)
discard = 0
filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/lambda:"*string(lambda)*
            "-d:"*string(d)*"-Nobs:"*string(Nobs)*"-mb_size:"*string(mb_size)*".jld"
xt_skel, bt_skel = load(filename, "xt_skeleton", "bt_skeleton")
xi_samples_gzz = extract_samples(xt_skel[:,discard+1:end], 
                             bt_skel[:,discard+1:end], 
                            (bt_skel[end]-bt_skel[discard+1])/n_samples,
                            "linear")[:,1:end-1]
iacts_gzz = zeros(size(xi_samples_gzz,1))
for dim in 1:size(xi_samples_gzz,1)
    a = acf(xi_samples_gzz[dim,:],maxlag_gzz)
    plot(a)
    acfs_gzz[dim,:] = a
end
title("ACFs for GZZ")
xlabel("Lag")
ylabel("ACF")
grid(true)
xt_skel, bt_skel, xi_samples = [], [], []
gc()
# Out:
# PyPlot.Figure(PyObject <Figure size 500x300 with 1 Axes>)

# %%
gzz_mixing = n_samples/maximum(sum(acfs_gzz[:,1:80],2))
gzz_cost = max_attempts*mb_size;

# %%
(gzz_mixing/gzz_cost)./(hmc_mixing./hmc_cost)
# Out:
# 11-element Array{Float64,1}:
#    4.01924
#    2.75665
#    3.93063
#    4.19533
#    1.94355
#    3.30415
#    3.33029
#    4.2492
#    6.72314
#    7.28237
#  Inf
