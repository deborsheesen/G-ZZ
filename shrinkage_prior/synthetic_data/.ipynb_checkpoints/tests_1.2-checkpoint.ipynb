# %%
using Distributions, TimeIt, ProgressMeter, PyPlot, JLD
include("/home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl")
include("temp.jl")
# Out:
# run_sampler (generic function with 4 methods)

# %% [raw]
# d, Nobs = 51, 100
# pX = 1e0
# pξ = 1e-1
# X = sprandn(d, Nobs, pX)
# X[1,:] = 1
# ξ_true = sprandn(d, pξ)
# y = Float64.([rand(Binomial(1, 1/(1+exp(-ξ_true'X[:,j])))) for j in 1:Nobs])
# save("shrinkage_data_1_2.jld", "X", X, "y", y)

# %%
X, y = load("shrinkage_data_1_2.jld", "X", "y")
d, Nobs = size(X)
σ02 = 1
my_pr = SS_prior(d, σ02)
my_ll = ll_logistic_sp(X,y)
my_model = model(my_ll, my_pr);

# %% [markdown]
# ### GZZ:

# %%
# Sub-sampling without control variates and with weights:
mb_size = 1
max_attempts = 10^7
lambda = 5e1
Print = true;

# %%
start = time()
run_sampler(my_model, lambda, max_attempts, mb_size, Print) 
print("Sampling in ", round((time()-start)/60,1), " mins \n")
# Out:
# 10 percent attempts in 4.56 min; zz bounces = 101069, hyp bounces = 11771, total time of process = 239.195
# 20 percent attempts in 9.15 min; zz bounces = 192545, hyp bounces = 23832, total time of process = 478.963
# 30 percent attempts in 13.61 min; zz bounces = 267025, hyp bounces = 35953, total time of process = 719.441
# 40 percent attempts in 18.29 min; zz bounces = 352395, hyp bounces = 47997, total time of process = 959.098
# 50 percent attempts in 22.88 min; zz bounces = 429691, hyp bounces = 60087, total time of process = 1199.053
# 60 percent attempts in 27.73 min; zz bounces = 519953, hyp bounces = 71888, total time of process = 1438.209
# 70 percent attempts in 32.51 min; zz bounces = 597446, hyp bounces = 83841, total time of process = 1678.542
# 80 percent attempts in 37.12 min; zz bounces = 669451, hyp bounces = 95852, total time of process = 1919.300
# 90 percent attempts in 41.66 min; zz bounces = 736677, hyp bounces = 107883, total time of process = 2159.779
# 100 percent attempts in 46.34 min; zz bounces = 815571, hyp bounces = 119874, total time of process = 2399.830
# Sampling in 46.4 mins

# %%
fig = figure("pyplot_barplot",figsize=(5,3))
n_samples = 10^4
maxlag_gzz = 500
acfs_gzz = zeros(d,maxlag_gzz)
discard = 0
filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/lambda:"*string(lambda)*
            "-d:"*string(d)*"-Nobs:"*string(Nobs)*"-mb_size:"*string(mb_size)*".jld"
xt_skel, bt_skel = load(filename, "xt_skeleton", "bt_skeleton")
xi_samples_gzz = extract_samples(xt_skel[:,discard+1:end], 
                             bt_skel[:,discard+1:end], 
                            (bt_skel[end]-bt_skel[discard+1])/n_samples,
                            "linear")[:,1:end-1]
iacts_gzz = zeros(size(xi_samples_gzz,1))
for dim in 1:size(xi_samples_gzz,1)
    a = acf(xi_samples_gzz[dim,:],maxlag_gzz)
    plot(a)
    acfs_gzz[dim,:] = a
end
title("ACFs for GZZ")
xlabel("Lag")
ylabel("ACF")
grid(true)
xt_skel, bt_skel, xi_samples = [], [], []
gc()
# Out:
# PyPlot.Figure(PyObject <Figure size 500x300 with 1 Axes>)

# %% [markdown]
# ### HMC:

# %% [markdown]
# ### Tune HMC:

# %%
ξ0 = randn(d)
Total_time = 10
T = 250
Metropolise = false
Print = false
n_leapfrog_list = 20*(1:5);

# %%
prior = SS_prior(d, σ02)
xi_samples_hmc, hyper_samples_hmc, acc = 
zeros(d,T+1,length(n_leapfrog_list)), zeros(hyperparam_size(prior),T+1,length(n_leapfrog_list)), 
zeros(length(n_leapfrog_list));

# %%
for (i,n_leapfrog) in enumerate(reverse(n_leapfrog_list))
    start = time()
    prior = SS_prior(d, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    stepsize = Total_time/n_leapfrog
    xi_samples_hmc[:,:,i], hyper_samples_hmc[:,:,i], acc[i] = 
    GibbsHMC(my_model, ξ0, stepsize, n_leapfrog, T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
end
# Out:
# HMC acceptance = 100.0 percent; n_leapfrog = 100 in 2.04 mins
# HMC acceptance = 100.0 percent; n_leapfrog = 80 in 1.72 mins
# HMC acceptance = 100.0 percent; n_leapfrog = 60 in 1.3 mins
# ArgumentError: InverseGamma: the condition α > zero(α) && θ > zero(θ) is not satisfied.
#
# Stacktrace:
#  [1] macro expansion at /home/postdoc/dsen/.julia/v0.6/Distributions/src/utils.jl:6 [inlined]
#  [2] Distributions.InverseGamma{Float64}(::Float64, ::Float64) at /home/postdoc/dsen/.julia/v0.6/Distributions/src/univariate/continuous/inversegamma.jl:33
#  [3] (::##505#511{SS_prior,Array{Float64,1}})(::Int64) at ./<missing>:0
#  [4] collect(::Base.Generator{UnitRange{Int64},##505#511{SS_prior,Array{Float64,1}}}) at ./array.jl:470
#  [5] block_Gibbs_update_hyperparams(::SS_prior, ::Array{Float64,1}) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/priors.jl:153
#  [6] GibbsHMC(::model, ::Array{Float64,1}, ::Float64, ::Int64, ::Int64, ::Bool, ::Bool) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl:632
#  [7] macro expansion at ./In[18]:7 [inlined]
#  [8] anonymous at ./<missing>:?
#  [9] include_string(::String, ::String) at ./loading.jl:522

# %%
Metropolise = true 
Print = false

stepsize = Total_time/50
total_times = 5*stepsize*(5:15)
n_leapfrog_steps = 5*(1:10)

for total_time in total_times
    print("Total time = ", round(total_time,2), "\n")
    for n_leapfrog in n_leapfrog_steps
        start = time()
        prior = SS_prior(d, σ02)
        my_ll = ll_logistic_sp(X,y)
        my_model = model(my_ll, prior)
        a, b, c = 
        GibbsHMC(my_model, ξ0, total_time/n_leapfrog, n_leapfrog, 500, Metropolise, Print)
        print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
    end
end
# Out:
# Total time = 5.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.26 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 10 in 0.46 mins
# HMC acceptance = 4.6 percent; n_leapfrog = 15 in 0.68 mins
# HMC acceptance = 37.8 percent; n_leapfrog = 20 in 0.9 mins
# HMC acceptance = 65.4 percent; n_leapfrog = 25 in 1.11 mins
# HMC acceptance = 77.2 percent; n_leapfrog = 30 in 1.3 mins
# HMC acceptance = 85.4 percent; n_leapfrog = 35 in 1.55 mins
# HMC acceptance = 89.2 percent; n_leapfrog = 40 in 1.73 mins
# HMC acceptance = 93.8 percent; n_leapfrog = 45 in 1.91 mins
# HMC acceptance = 95.8 percent; n_leapfrog = 50 in 2.07 mins
# Total time = 6.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.24 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.43 mins
# HMC acceptance = 1.2 percent; n_leapfrog = 15 in 0.63 mins
# HMC acceptance = 9.0 percent; n_leapfrog = 20 in 0.83 mins
# HMC acceptance = 41.0 percent; n_leapfrog = 25 in 1.02 mins
# HMC acceptance = 69.6 percent; n_leapfrog = 30 in 1.23 mins
# HMC acceptance = 75.2 percent; n_leapfrog = 35 in 1.41 mins
# HMC acceptance = 88.0 percent; n_leapfrog = 40 in 1.6 mins
# HMC acceptance = 89.8 percent; n_leapfrog = 45 in 1.79 mins
# HMC acceptance = 92.0 percent; n_leapfrog = 50 in 2.0 mins
# Total time = 7.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.24 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.44 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 15 in 0.63 mins
# HMC acceptance = 3.8 percent; n_leapfrog = 20 in 0.81 mins
# HMC acceptance = 16.2 percent; n_leapfrog = 25 in 1.01 mins
# HMC acceptance = 42.4 percent; n_leapfrog = 30 in 1.2 mins
# HMC acceptance = 63.2 percent; n_leapfrog = 35 in 1.4 mins
# HMC acceptance = 77.4 percent; n_leapfrog = 40 in 1.6 mins
# HMC acceptance = 80.6 percent; n_leapfrog = 45 in 1.8 mins
# HMC acceptance = 88.4 percent; n_leapfrog = 50 in 1.99 mins
# Total time = 8.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.24 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.43 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.63 mins
# HMC acceptance = 1.2 percent; n_leapfrog = 20 in 0.83 mins
# HMC acceptance = 6.0 percent; n_leapfrog = 25 in 1.05 mins
# HMC acceptance = 13.6 percent; n_leapfrog = 30 in 1.23 mins
# HMC acceptance = 35.8 percent; n_leapfrog = 35 in 1.4 mins
# HMC acceptance = 60.2 percent; n_leapfrog = 40 in 1.59 mins
# HMC acceptance = 73.4 percent; n_leapfrog = 45 in 1.79 mins
# HMC acceptance = 80.4 percent; n_leapfrog = 50 in 1.98 mins
# Total time = 9.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.24 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.43 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.63 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 20 in 0.82 mins
# HMC acceptance = 1.2 percent; n_leapfrog = 25 in 1.02 mins
# HMC acceptance = 5.0 percent; n_leapfrog = 30 in 1.21 mins
# HMC acceptance = 22.2 percent; n_leapfrog = 35 in 1.41 mins
# HMC acceptance = 41.2 percent; n_leapfrog = 40 in 1.62 mins
# HMC acceptance = 62.8 percent; n_leapfrog = 45 in 1.81 mins
# HMC acceptance = 71.0 percent; n_leapfrog = 50 in 2.0 mins
# Total time = 10.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.24 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.43 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.62 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.82 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 25 in 1.01 mins
# HMC acceptance = 5.0 percent; n_leapfrog = 30 in 1.22 mins
# HMC acceptance = 13.2 percent; n_leapfrog = 35 in 1.4 mins
# HMC acceptance = 16.8 percent; n_leapfrog = 40 in 1.61 mins
# HMC acceptance = 55.0 percent; n_leapfrog = 45 in 1.8 mins
# HMC acceptance = 56.2 percent; n_leapfrog = 50 in 2.02 mins
# Total time = 11.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.24 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.43 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.63 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.83 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.03 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 30 in 1.22 mins
# HMC acceptance = 2.0 percent; n_leapfrog = 35 in 1.42 mins
# HMC acceptance = 12.6 percent; n_leapfrog = 40 in 1.58 mins
# HMC acceptance = 30.6 percent; n_leapfrog = 45 in 1.79 mins
# HMC acceptance = 52.4 percent; n_leapfrog = 50 in 1.98 mins
# Total time = 12.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.24 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.43 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.62 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.83 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.02 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 30 in 1.23 mins
# HMC acceptance = 1.6 percent; n_leapfrog = 35 in 1.42 mins
# HMC acceptance = 3.8 percent; n_leapfrog = 40 in 1.61 mins
# HMC acceptance = 12.2 percent; n_leapfrog = 45 in 1.8 mins
# HMC acceptance = 26.6 percent; n_leapfrog = 50 in 2.0 mins
# Total time = 13.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.24 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.43 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.63 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.81 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.01 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 1.21 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 35 in 1.41 mins
# HMC acceptance = 2.4 percent; n_leapfrog = 40 in 1.68 mins
# HMC acceptance = 5.6 percent; n_leapfrog = 45 in 1.88 mins
# HMC acceptance = 14.2 percent; n_leapfrog = 50 in 2.0 mins
# Total time = 14.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.24 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.44 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.65 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.87 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.08 mins
# InterruptException:
#
# Stacktrace:
#  [1] Ac_mul_B(::Array{Float64,1}, ::SparseMatrixCSC{Float64,Int64}) at ./linalg/rowvector.jl:227
#  [2] partial_derivative_vec(::ll_logistic_sp, ::Array{Float64,1}, ::Int64, ::UnitRange{Int64}) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/models.jl:32
#  [3] #481 at ./<missing>:0 [inlined]
#  [4] next at ./generator.jl:45 [inlined]
#  [5] collect_to!(::Array{Float64,1}, ::Base.Generator{UnitRange{Int64},##481#482{ll_logistic_sp,Array{Float64,1}}}, ::Int64, ::Int64) at ./array.jl:503
#  [6] collect(::Base.Generator{UnitRange{Int64},##481#482{ll_logistic_sp,Array{Float64,1}}}) at ./array.jl:471
#  [7] gradient(::model, ::Array{Float64,1}) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/models.jl:66
#  [8] HMC(::model, ::Array{Float64,1}, ::Float64, ::Int64, ::Bool) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl:594
#  [9] GibbsHMC(::model, ::Array{Float64,1}, ::Float64, ::Int64, ::Int64, ::Bool, ::Bool) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl:629
#  [10] macro expansion at ./In[19]:15 [inlined]
#  [11] anonymous at ./<missing>:?
#  [12] include_string(::String, ::String) at ./loading.jl:522

# %%
total_times_optimal = 5:11
n_leapfrog_optimal = [25,30,35,40,58,55,60]
T = 2500
Metropolise = true
Print = false

for (i,total_time) in enumerate(total_times_optimal) 
    start = time()
    prior = SS_prior(d, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    xi_samples_hmc, hyper_samples_hmc, acc =
    GibbsHMC(my_model, ξ0, total_time/n_leapfrog_optimal[i], n_leapfrog_optimal[i], T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog_optimal[i], " in ", round((time()-start)/60,2), " mins \n")
    filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/GibbsHMC:d:"*string(d)*"-Nobs:"*string(Nobs)*
                "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog_optimal[i])*".jld"
    save(filename, "xi_samples", xi_samples_hmc, "hyper_samples", hyper_samples_hmc, "acc", acc)
    xi_samples_hmc, hyper_samples_hmc, acc = [], [], []
    gc()
end
# Out:
# HMC acceptance = 65.92 percent; n_leapfrog = 25 in 5.18 mins
# HMC acceptance = 66.36 percent; n_leapfrog = 30 in 6.0 mins
# HMC acceptance = 63.52 percent; n_leapfrog = 35 in 7.31 mins
# HMC acceptance = 64.04 percent; n_leapfrog = 40 in 8.02 mins
# HMC acceptance = 79.6 percent; n_leapfrog = 58 in 12.41 mins
# HMC acceptance = 71.4 percent; n_leapfrog = 55 in 11.29 mins
# InterruptException:
#
# Stacktrace:
#  [1] broadcast_t at ./broadcast.jl:268 [inlined]
#  [2] broadcast_c at ./broadcast.jl:316 [inlined]
#  [3] broadcast at ./broadcast.jl:455 [inlined]
#  [4] +(::Array{Float64,1}, ::Array{Float64,1}) at ./arraymath.jl:39
#  [5] get_σ2(::SS_prior) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/priors.jl:137
#  [6] collect_to!(::Array{Float64,1}, ::Base.Generator{UnitRange{Int64},##491#492{SS_prior,Array{Float64,1}}}, ::Int64, ::Int64) at ./array.jl:503
#  [7] collect(::Base.Generator{UnitRange{Int64},##491#492{SS_prior,Array{Float64,1}}}) at ./array.jl:471
#  [8] gradient(::model, ::Array{Float64,1}) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/models.jl:66
#  [9] HMC(::model, ::Array{Float64,1}, ::Float64, ::Int64, ::Bool) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl:594
#  [10] GibbsHMC(::model, ::Array{Float64,1}, ::Float64, ::Int64, ::Int64, ::Bool, ::Bool) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl:629
#  [11] macro expansion at ./In[25]:12 [inlined]
#  [12] anonymous at ./<missing>:?
#  [13] include_string(::String, ::String) at ./loading.jl:522

# %%
maxlag_hmc = 200
fig = figure(figsize=(12,4))
acfs_hmc = zeros(length(total_times_optimal),size(xi_samples_hmc,1),maxlag_hmc)

for i in 1:2 
    for j in 1:4
        k = 4*(i-1)+j
        if k < 7
            total_time, n_leapfrog = total_times_optimal[k], n_leapfrog_optimal[k]
            filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/GibbsHMC:d:"*
                        string(d)*"-Nobs:"*string(Nobs)*
                        "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog)*".jld"
            xi_samples_hmc = load(filename, "xi_samples")

            subplot(2,4,k)
            for dim in 1:size(xi_samples_hmc,1) 
                a = acf(xi_samples_hmc[dim,:], maxlag_hmc)
                plot(a)
                acfs_hmc[k,dim,:] = a
            end
            grid(true)  
            title("Total time:"*string(total_time)*", n_leapfrog:"*string(n_leapfrog), fontsize=10)
            xi_samples_hmc = []
            gc()
            if i == 2 xlabel("Lag") end
            if i == 1 xticks(alpha=0) end
            if j == 1 ylabel("ACF") end
        end
    end
end
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x400 with 6 Axes>)

# %%
hmc_mixing = T./maximum(sum(acfs_hmc[:,:,1:100],3),2)
hmc_cost = T*n_leapfrog_optimal*Nobs
gzz_mixing = n_samples/maximum(sum(acfs_gzz[:,1:500],2))
gzz_cost = max_attempts*mb_size;

# %%
(gzz_mixing/gzz_cost)./(hmc_mixing./hmc_cost)
# Out:
# 7×1×1 Array{Float64,3}:
# [:, :, 1] =
#  0.178716
#  0.479505
#  0.414681
#  0.507285
#  0.778139
#  0.291508
#  0.0
