# %%
using Distributions, TimeIt, ProgressMeter, PyPlot, JLD
include("/home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl")
include("temp.jl")
# Out:
# run_sampler (generic function with 4 methods)

# %%
Nobs_list = 100*(1:10)
performance = [0.066,0.319,0.972,1.712,1.480,2.562,2.552,1.944,2.261,5.634];

# %%
fig = figure("pyplot_barplot",figsize=(6,3))
plot(Nobs_list, performance, "o")
grid(true)
xlabel("n")
ylabel("Relative efficiency")
title("Relative efficiency of Gibbs zig-zag over Hamiltonian Monte Carlo", fontsize=11)
savefig("/home/postdoc/dsen/Desktop/G-ZZ/plots/shrinkage_GZZvsHMC.pdf", 
    format="pdf", dpi=10_000, bbox_inches="tight")
# Out:
# PyPlot.Figure(PyObject <Figure size 600x300 with 1 Axes>)
