# %%
using Distributions, TimeIt, ProgressMeter, PyPlot, JLD
include("/home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl")
include("temp.jl")
# Out:
# run_sampler (generic function with 4 methods)

# %%
X, y = load("shrinkage_data_2.1.jld", "X", "y")
d, Nobs = size(X)
σ02 = 1
my_pr = SS_prior(d, σ02)
my_ll = ll_logistic_sp(X,y)
my_model = model(my_ll, my_pr);

# %% [markdown]
# ### HMC:

# %% [markdown]
# ### Tune HMC:

# %%
ξ0 = randn(d)
Total_time = 10
T = 250
Metropolise = false
Print = false
n_leapfrog_list = 20*(1:5)
prior = SS_prior(d, σ02);

# %%
xi_samples_hmc, hyper_samples_hmc, acc = 
zeros(d,T+1,length(n_leapfrog_list)), zeros(hyperparam_size(prior),T+1,length(n_leapfrog_list)), 
zeros(length(n_leapfrog_list));

# %%
for (i,n_leapfrog) in enumerate(reverse(n_leapfrog_list))
    start = time()
    prior = SS_prior(d, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    stepsize = Total_time/n_leapfrog
    xi_samples_hmc[:,:,i], hyper_samples_hmc[:,:,i], acc[i] = 
    GibbsHMC(my_model, ξ0, stepsize, n_leapfrog, T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
end
# Out:
# HMC acceptance = 100.0 percent; n_leapfrog = 100 in 4.06 mins
# HMC acceptance = 100.0 percent; n_leapfrog = 80 in 3.28 mins
# HMC acceptance = 100.0 percent; n_leapfrog = 60 in 2.44 mins
# ArgumentError: InverseGamma: the condition α > zero(α) && θ > zero(θ) is not satisfied.
#
# Stacktrace:
#  [1] macro expansion at /home/postdoc/dsen/.julia/v0.6/Distributions/src/utils.jl:6 [inlined]
#  [2] Distributions.InverseGamma{Float64}(::Float64, ::Float64) at /home/postdoc/dsen/.julia/v0.6/Distributions/src/univariate/continuous/inversegamma.jl:33
#  [3] (::##505#511{SS_prior,Array{Float64,1}})(::Int64) at ./<missing>:0
#  [4] collect(::Base.Generator{UnitRange{Int64},##505#511{SS_prior,Array{Float64,1}}}) at ./array.jl:470
#  [5] block_Gibbs_update_hyperparams(::SS_prior, ::Array{Float64,1}) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/priors.jl:153
#  [6] GibbsHMC(::model, ::Array{Float64,1}, ::Float64, ::Int64, ::Int64, ::Bool, ::Bool) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl:634
#  [7] macro expansion at ./In[5]:7 [inlined]
#  [8] anonymous at ./<missing>:?
#  [9] include_string(::String, ::String) at ./loading.jl:522

# %%
Metropolise = true 
Print = false

stepsize = Total_time/50
total_times = 4*stepsize*(5:15)
n_leapfrog_steps = 5*(1:10)

for total_time in total_times
    print("Total time = ", round(total_time,2), "\n")
    for n_leapfrog in n_leapfrog_steps
        start = time()
        prior = SS_prior(d, σ02)
        my_ll = ll_logistic_sp(X,y)
        my_model = model(my_ll, prior)
        a, b, c = 
        GibbsHMC(my_model, ξ0, total_time/n_leapfrog, n_leapfrog, 500, Metropolise, Print)
        print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
    end
end
# Out:
# Total time = 4.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.46 mins
# HMC acceptance = 3.4 percent; n_leapfrog = 10 in 0.89 mins
# HMC acceptance = 50.4 percent; n_leapfrog = 15 in 1.27 mins
# HMC acceptance = 76.6 percent; n_leapfrog = 20 in 1.66 mins
# HMC acceptance = 87.4 percent; n_leapfrog = 25 in 2.09 mins
# HMC acceptance = 92.8 percent; n_leapfrog = 30 in 2.48 mins
# HMC acceptance = 96.0 percent; n_leapfrog = 35 in 2.89 mins
# HMC acceptance = 96.4 percent; n_leapfrog = 40 in 3.28 mins
# HMC acceptance = 95.0 percent; n_leapfrog = 45 in 3.66 mins
# HMC acceptance = 97.8 percent; n_leapfrog = 50 in 4.09 mins
# Total time = 4.8
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.48 mins
# HMC acceptance = 0.8 percent; n_leapfrog = 10 in 0.88 mins
# HMC acceptance = 25.8 percent; n_leapfrog = 15 in 1.27 mins
# HMC acceptance = 62.8 percent; n_leapfrog = 20 in 1.67 mins
# HMC acceptance = 85.6 percent; n_leapfrog = 25 in 2.09 mins
# HMC acceptance = 88.4 percent; n_leapfrog = 30 in 2.48 mins
# HMC acceptance = 89.8 percent; n_leapfrog = 35 in 2.86 mins
# HMC acceptance = 93.4 percent; n_leapfrog = 40 in 3.31 mins
# HMC acceptance = 95.6 percent; n_leapfrog = 45 in 3.66 mins
# HMC acceptance = 96.4 percent; n_leapfrog = 50 in 4.09 mins
# Total time = 5.6
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.48 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.88 mins
# HMC acceptance = 8.8 percent; n_leapfrog = 15 in 1.32 mins
# HMC acceptance = 35.0 percent; n_leapfrog = 20 in 1.73 mins
# HMC acceptance = 67.8 percent; n_leapfrog = 25 in 2.1 mins
# HMC acceptance = 82.2 percent; n_leapfrog = 30 in 2.51 mins
# HMC acceptance = 84.8 percent; n_leapfrog = 35 in 2.88 mins
# HMC acceptance = 94.2 percent; n_leapfrog = 40 in 3.31 mins
# HMC acceptance = 94.0 percent; n_leapfrog = 45 in 3.71 mins
# HMC acceptance = 94.6 percent; n_leapfrog = 50 in 4.12 mins
# Total time = 6.4
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.49 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.88 mins
# HMC acceptance = 5.4 percent; n_leapfrog = 15 in 1.28 mins
# HMC acceptance = 18.0 percent; n_leapfrog = 20 in 1.72 mins
# HMC acceptance = 61.4 percent; n_leapfrog = 25 in 2.13 mins
# HMC acceptance = 74.2 percent; n_leapfrog = 30 in 2.47 mins
# HMC acceptance = 82.0 percent; n_leapfrog = 35 in 2.93 mins
# HMC acceptance = 84.6 percent; n_leapfrog = 40 in 3.28 mins
# HMC acceptance = 92.6 percent; n_leapfrog = 45 in 3.66 mins
# HMC acceptance = 96.0 percent; n_leapfrog = 50 in 4.13 mins
# Total time = 7.2
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.5 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.89 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 15 in 1.3 mins
# HMC acceptance = 4.4 percent; n_leapfrog = 20 in 1.68 mins
# HMC acceptance = 32.8 percent; n_leapfrog = 25 in 2.12 mins
# HMC acceptance = 56.6 percent; n_leapfrog = 30 in 2.51 mins
# HMC acceptance = 73.2 percent; n_leapfrog = 35 in 2.86 mins
# HMC acceptance = 85.0 percent; n_leapfrog = 40 in 3.27 mins
# HMC acceptance = 89.6 percent; n_leapfrog = 45 in 3.81 mins
# HMC acceptance = 92.2 percent; n_leapfrog = 50 in 4.23 mins
# Total time = 8.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.5 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.9 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.29 mins
# HMC acceptance = 1.0 percent; n_leapfrog = 20 in 1.68 mins
# HMC acceptance = 19.0 percent; n_leapfrog = 25 in 2.12 mins
# HMC acceptance = 44.6 percent; n_leapfrog = 30 in 2.54 mins
# HMC acceptance = 58.8 percent; n_leapfrog = 35 in 2.86 mins
# HMC acceptance = 75.8 percent; n_leapfrog = 40 in 3.33 mins
# HMC acceptance = 82.4 percent; n_leapfrog = 45 in 3.67 mins
# HMC acceptance = 89.4 percent; n_leapfrog = 50 in 4.09 mins
# Total time = 8.8
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.48 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.88 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.27 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 20 in 1.71 mins
# HMC acceptance = 5.8 percent; n_leapfrog = 25 in 2.12 mins
# HMC acceptance = 27.8 percent; n_leapfrog = 30 in 2.55 mins
# HMC acceptance = 38.2 percent; n_leapfrog = 35 in 2.89 mins
# HMC acceptance = 66.4 percent; n_leapfrog = 40 in 3.28 mins
# HMC acceptance = 78.6 percent; n_leapfrog = 45 in 3.65 mins
# HMC acceptance = 84.4 percent; n_leapfrog = 50 in 4.16 mins
# Total time = 9.6
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.48 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.89 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.3 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.68 mins
# HMC acceptance = 2.4 percent; n_leapfrog = 25 in 2.09 mins
# HMC acceptance = 17.2 percent; n_leapfrog = 30 in 2.52 mins
# HMC acceptance = 25.0 percent; n_leapfrog = 35 in 2.92 mins
# HMC acceptance = 56.6 percent; n_leapfrog = 40 in 3.54 mins
# HMC acceptance = 68.8 percent; n_leapfrog = 45 in 3.7 mins
# HMC acceptance = 77.4 percent; n_leapfrog = 50 in 4.09 mins
# Total time = 10.4
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.48 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.9 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.3 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.71 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 25 in 2.08 mins
# HMC acceptance = 4.2 percent; n_leapfrog = 30 in 2.58 mins
# HMC acceptance = 17.6 percent; n_leapfrog = 35 in 2.87 mins
# HMC acceptance = 41.6 percent; n_leapfrog = 40 in 3.29 mins
# HMC acceptance = 61.2 percent; n_leapfrog = 45 in 3.71 mins
# HMC acceptance = 69.4 percent; n_leapfrog = 50 in 4.17 mins
# Total time = 11.2
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.49 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.88 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.27 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.67 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 2.08 mins
# HMC acceptance = 6.4 percent; n_leapfrog = 30 in 2.47 mins
# HMC acceptance = 6.4 percent; n_leapfrog = 35 in 2.9 mins
# HMC acceptance = 24.0 percent; n_leapfrog = 40 in 3.31 mins
# HMC acceptance = 47.8 percent; n_leapfrog = 45 in 3.73 mins
# HMC acceptance = 57.4 percent; n_leapfrog = 50 in 4.1 mins
# Total time = 12.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.48 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.88 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.28 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.59 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.95 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 30 in 2.38 mins
# HMC acceptance = 4.0 percent; n_leapfrog = 35 in 2.62 mins
# HMC acceptance = 11.8 percent; n_leapfrog = 40 in 2.82 mins
# HMC acceptance = 24.2 percent; n_leapfrog = 45 in 3.16 mins
# HMC acceptance = 53.4 percent; n_leapfrog = 50 in 3.51 mins

# %%
total_times_optimal = [4.0, 4.8, 5.6, 6.4, 7.2, 8.0, 8.8, 9.6, 10.4]
n_leapfrog_optimal =  [17 , 20 , 25 , 27 , 32 , 36 , 40 , 43 , 47  ]
T = 5000
Metropolise = true
Print = false

for (i,total_time) in enumerate(total_times_optimal) 
    start = time()
    prior = SS_prior(d, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    xi_samples_hmc, hyper_samples_hmc, acc =
    GibbsHMC(my_model, ξ0, total_time/n_leapfrog_optimal[i], n_leapfrog_optimal[i], T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog_optimal[i], " in ", round((time()-start)/60,2), " mins \n")
    filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/GibbsHMC:d:"*string(d)*"-Nobs:"*string(Nobs)*
                "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog_optimal[i])*".jld"
    save(filename, "xi_samples", xi_samples_hmc, "hyper_samples", hyper_samples_hmc, "acc", acc)
    xi_samples_hmc, hyper_samples_hmc, acc = [], [], []
    gc()
end
# Out:
# HMC acceptance = 64.98 percent; n_leapfrog = 17 in 16.45 mins
# HMC acceptance = 61.14 percent; n_leapfrog = 20 in 17.69 mins
# HMC acceptance = 67.64 percent; n_leapfrog = 25 in 20.56 mins
# HMC acceptance = 60.64 percent; n_leapfrog = 27 in 21.69 mins
# HMC acceptance = 65.86 percent; n_leapfrog = 32 in 24.51 mins
# HMC acceptance = 65.64 percent; n_leapfrog = 36 in 27.3 mins
# HMC acceptance = 65.52 percent; n_leapfrog = 40 in 30.26 mins
# HMC acceptance = 65.92 percent; n_leapfrog = 43 in 32.56 mins
# HMC acceptance = 64.28 percent; n_leapfrog = 47 in 34.32 mins

# %%
total_times_optimal = [4.0, 4.8, 5.6, 6.4, 7.2, 8.0, 8.8, 9.6, 10.4]
n_leapfrog_optimal =  [17 , 20 , 25 , 27 , 32 , 36 , 40 , 43 , 47  ];

# %%
maxlag_hmc = 500
fig = figure(figsize=(12,4))
acfs_hmc = zeros(length(total_times_optimal),d,maxlag_hmc)

for i in 1:2 
    for j in 1:5
        k = 5*(i-1)+j
        if k < 10 
            total_time, n_leapfrog = total_times_optimal[k], n_leapfrog_optimal[k]
            filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/GibbsHMC:d:"*
                        string(d)*"-Nobs:"*string(Nobs)*
                       "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog)*".jld"
            xi_samples_hmc = load(filename, "xi_samples")

            subplot(2,5,k)
            for dim in 1:size(xi_samples_hmc,1) 
                a = acf(xi_samples_hmc[dim,:], maxlag_hmc)
                plot(a)
                acfs_hmc[k,dim,:] = a
            end
            grid(true)  
            title("Total time:"*string(total_time)*", \n n_leapfrog:"*string(n_leapfrog), fontsize=10)
            xi_samples_hmc = []
            gc()
            if i == 2 xlabel("Lag") end
            if j == 1 ylabel("ACF") end
            subplots_adjust(hspace=0.5)
        end
    end
end
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x400 with 9 Axes>)

# %%
T = 5000
maxlag_hmc_list = [50, 200, 50, 100, 100, 200, 100, 100, 250]
hmc_mixing = zeros(length(total_times_optimal))
for i in 1:length(total_times_optimal)
    hmc_mixing[i] = T/maximum(sum(acfs_hmc[i,:,1:maxlag_hmc_list[i]],2))
end
hmc_cost = T*n_leapfrog_optimal*Nobs;

# %%
mb_size = 1
max_attempts = 10^7
lambda = 2e1

fig = figure("pyplot_barplot",figsize=(5,3))
n_samples = 10^4
maxlag_gzz = 1500
acfs_gzz = zeros(d,maxlag_gzz)
discard = 0
filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/lambda:"*string(lambda)*
            "-d:"*string(d)*"-Nobs:"*string(Nobs)*"-mb_size:"*string(mb_size)*".jld"
xt_skel, bt_skel = load(filename, "xt_skeleton", "bt_skeleton")
xi_samples_gzz = extract_samples(xt_skel[:,discard+1:end], 
                             bt_skel[:,discard+1:end], 
                            (bt_skel[end]-bt_skel[discard+1])/n_samples,
                            "linear")[:,1:end-1]
iacts_gzz = zeros(size(xi_samples_gzz,1))
for dim in 1:size(xi_samples_gzz,1)
    a = acf(xi_samples_gzz[dim,:],maxlag_gzz)
    plot(a)
    acfs_gzz[dim,:] = a
end
title("ACFs for GZZ")
xlabel("Lag")
ylabel("ACF")
grid(true)
xt_skel, bt_skel, xi_samples = [], [], []
gc()
# Out:
# PyPlot.Figure(PyObject <Figure size 500x300 with 1 Axes>)

# %%
gzz_mixing = n_samples/maximum(sum(acfs_gzz[:,1:1000],2))
gzz_cost = max_attempts*mb_size;

# %%
minimum((gzz_mixing/gzz_cost)./(hmc_mixing./hmc_cost))
# Out:
# 0.06646675934402255
