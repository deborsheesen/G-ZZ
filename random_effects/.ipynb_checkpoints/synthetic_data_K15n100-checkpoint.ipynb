# %%
using Distributions, TimeIt, ProgressMeter, PyPlot
include("/home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl")
include("temp.jl")
# Out:
# run_sampler (generic function with 3 methods)

# %% [markdown]
# #### Simulate data:

# %%
n_groups, group_size = 15, 100
Nobs = group_size*n_groups
d = 5
dim_total = 1+n_groups+d

σ02 = 1
my_pr = MM_prior(d, n_groups, σ02);

# %%
pX = 5e-2
X = spzeros(dim_total, Nobs)
X[1,:] = 1
for group in 1:n_groups
    X[group+1,((group-1)*group_size+1):(group*group_size)] = 1
end
X[n_groups+2:end,:] = sprandn(d, Nobs, pX)
ξ_true = rand(Normal(),dim_total)
y = Float64.([rand(Binomial(1, 1/(1+exp(-ξ_true'X[:,j])))) for j in 1:Nobs])
my_ll = ll_logistic_sp(X,y)
my_model = model(my_ll, my_pr);

# %% [markdown]
# #### Run sampler:

# %%
mb_size = 1
max_attempts = 10^7
prob_het = 0.99
adapt_speed = "none"

lambda = 5e1
start = time()
Print = true
run_sampler(my_model, lambda, max_attempts, mb_size, Print, prob_het, adapt_speed)
print("Time = ", round((time()-start)/60,1), " mins")
# Out:
# 10 percent attempts in 2.50 min; zz bounces = 67507, hyp bounces = 6170, total time of process = 123.339
# 20 percent attempts in 5.20 min; zz bounces = 134866, hyp bounces = 12315, total time of process = 246.423
# 30 percent attempts in 7.86 min; zz bounces = 202138, hyp bounces = 18339, total time of process = 369.706
# 40 percent attempts in 10.61 min; zz bounces = 269807, hyp bounces = 24557, total time of process = 493.055
# 50 percent attempts in 13.47 min; zz bounces = 336912, hyp bounces = 30819, total time of process = 616.464
# 60 percent attempts in 16.10 min; zz bounces = 404825, hyp bounces = 36928, total time of process = 739.868
# 70 percent attempts in 18.64 min; zz bounces = 472221, hyp bounces = 42968, total time of process = 863.281
# 80 percent attempts in 21.24 min; zz bounces = 540093, hyp bounces = 49180, total time of process = 986.634
# 90 percent attempts in 23.82 min; zz bounces = 607636, hyp bounces = 55294, total time of process = 1110.104
# 100 percent attempts in 26.46 min; zz bounces = 675460, hyp bounces = 61601, total time of process = 1233.295
# Time = 26.6 mins

# %% [markdown]
# ### Plot ACFs:

# %%
fig = figure("pyplot_barplot",figsize=(5,3))
n_samples = 10^4
maxlag_gzz = 150
acfs_gzz = zeros(dim_total,maxlag_gzz)
discard = 0
filename = "/xtmp/GZZ_data/mixed_effects/lambda:"*string(lambda)*
        "-dim_cov:"*string(d)*"-n_groups:"*string(n_groups)*
        "-Nobs:"*string(Nobs)*"-mb_size:"*string(mb_size)*".jld"
xt_skel, bt_skel = load(filename, "xt_skeleton", "bt_skeleton")
xi_samples_gzz = extract_samples(xt_skel[:,discard+1:end], 
                                 bt_skel[:,discard+1:end], 
                                 (bt_skel[end]-bt_skel[discard+1])/n_samples,
                                 "linear")[:,1:end-1]
for dim in 1:size(xi_samples_gzz,1)
    a = acf(xi_samples_gzz[dim,:],maxlag_gzz)
    plot(a)
    acfs_gzz[dim,:] = a
end
grid(true)
xt_skel, bt_skel, xi_samples = [], [], []
gc()
# Out:
# PyPlot.Figure(PyObject <Figure size 500x300 with 1 Axes>)

# %% [markdown]
# ### Tune HMC:

# %%
ξ0 = randn(dim_total)
Total_time = 7
T = 250
Metropolise = false
Print = false
n_leapfrog_list = 20*(1:5)
# Out:
# 20:20:100

# %%
for (i,n_leapfrog) in enumerate(reverse(n_leapfrog_list))
    start = time()
    prior = MM_prior(d, n_groups, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    stepsize = Total_time/n_leapfrog
    xi_samples, hyper_samples, acc = 
    GibbsHMC(my_model, ξ0, stepsize, n_leapfrog, T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
end
# Out:
# HMC acceptance = 100.0 percent; n_leapfrog = 100 in 0.56 mins
# HMC acceptance = 100.0 percent; n_leapfrog = 80 in 0.45 mins
# ArgumentError: Gamma: the condition α > zero(α) && θ > zero(θ) is not satisfied.
#
# Stacktrace:
#  [1] macro expansion at /home/postdoc/dsen/.julia/v0.6/Distributions/src/utils.jl:6 [inlined]
#  [2] Distributions.Gamma{Float64}(::Float64, ::Float64) at /home/postdoc/dsen/.julia/v0.6/Distributions/src/univariate/continuous/gamma.jl:32
#  [3] block_Gibbs_update_hyperparams(::MM_prior, ::Array{Float64,1}) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/priors.jl:329
#  [4] GibbsHMC(::model, ::Array{Float64,1}, ::Float64, ::Int64, ::Int64, ::Bool, ::Bool) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl:634
#  [5] macro expansion at ./In[8]:7 [inlined]
#  [6] anonymous at ./<missing>:?
#  [7] include_string(::String, ::String) at ./loading.jl:522

# %%
Metropolise = true 
Print = false

stepsize = Total_time/70
total_times = 4*stepsize*(6:15)
n_leapfrog_steps = 5*(3:10)

for total_time in total_times
    print("Total time = ", round(total_time,2), "\n")
    for n_leapfrog in n_leapfrog_steps
        start = time()
        prior = MM_prior(d, n_groups, σ02)
        my_ll = ll_logistic_sp(X,y)
        my_model = model(my_ll, prior)
        a, b, c = 
        GibbsHMC(my_model, ξ0, total_time/n_leapfrog, n_leapfrog, 500, Metropolise, Print)
        print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
        if c > 0.7 
            break
        end
    end
end
# Out:
# Total time = 2.4
# HMC acceptance = 0.2 percent; n_leapfrog = 15 in 0.19 mins
# HMC acceptance = 31.6 percent; n_leapfrog = 20 in 0.25 mins
# HMC acceptance = 82.0 percent; n_leapfrog = 25 in 0.31 mins
# Total time = 2.8
# HMC acceptance = 0.2 percent; n_leapfrog = 15 in 0.19 mins
# HMC acceptance = 0.8 percent; n_leapfrog = 20 in 0.24 mins
# HMC acceptance = 52.4 percent; n_leapfrog = 25 in 0.3 mins
# HMC acceptance = 83.2 percent; n_leapfrog = 30 in 0.35 mins
# Total time = 3.2
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.18 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 20 in 0.24 mins
# HMC acceptance = 2.0 percent; n_leapfrog = 25 in 0.3 mins
# HMC acceptance = 53.8 percent; n_leapfrog = 30 in 0.36 mins
# HMC acceptance = 83.2 percent; n_leapfrog = 35 in 0.41 mins
# Total time = 3.6
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.18 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.24 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 25 in 0.3 mins
# HMC acceptance = 25.2 percent; n_leapfrog = 30 in 0.37 mins
# HMC acceptance = 61.2 percent; n_leapfrog = 35 in 0.42 mins
# HMC acceptance = 89.4 percent; n_leapfrog = 40 in 0.47 mins
# Total time = 4.0
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.19 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.25 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 25 in 0.3 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 30 in 0.36 mins
# HMC acceptance = 43.4 percent; n_leapfrog = 35 in 0.41 mins
# HMC acceptance = 67.4 percent; n_leapfrog = 40 in 0.46 mins
# HMC acceptance = 90.8 percent; n_leapfrog = 45 in 0.52 mins
# Total time = 4.4
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.18 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.24 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.31 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 30 in 0.36 mins
# HMC acceptance = 1.2 percent; n_leapfrog = 35 in 0.41 mins
# HMC acceptance = 52.2 percent; n_leapfrog = 40 in 0.47 mins
# HMC acceptance = 74.2 percent; n_leapfrog = 45 in 0.53 mins
# Total time = 4.8
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.18 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.24 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 25 in 0.29 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 30 in 0.35 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 35 in 0.4 mins
# HMC acceptance = 22.2 percent; n_leapfrog = 40 in 0.46 mins
# HMC acceptance = 55.2 percent; n_leapfrog = 45 in 0.51 mins
# HMC acceptance = 76.2 percent; n_leapfrog = 50 in 0.61 mins
# Total time = 5.2
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.19 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.25 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.31 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 30 in 0.35 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 35 in 0.41 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 40 in 0.45 mins
# HMC acceptance = 38.4 percent; n_leapfrog = 45 in 0.5 mins
# HMC acceptance = 61.8 percent; n_leapfrog = 50 in 0.52 mins
# Total time = 5.6
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.16 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.21 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.26 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 0.32 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 35 in 0.38 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 40 in 0.44 mins
# HMC acceptance = 3.6 percent; n_leapfrog = 45 in 0.49 mins
# HMC acceptance = 57.2 percent; n_leapfrog = 50 in 0.55 mins
# Total time = 6.0
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.16 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.21 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.26 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 0.31 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 35 in 0.36 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 40 in 0.41 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 45 in 0.47 mins
# HMC acceptance = 20.6 percent; n_leapfrog = 50 in 0.54 mins

# %%
total_times_optimal = round.(total_times,2)
n_leapfrog_optimal =  [23,27,32,36,40,43,47,51,52,60];

# %%
T = 5000
Metropolise = true
Print = false

for (i,total_time) in enumerate(total_times_optimal) 
    n_leapfrog = n_leapfrog_optimal[i]
    start = time()
    prior = MM_prior(d, n_groups, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    xi_samples_hmc, hyper_samples_hmc, acc =
    GibbsHMC(my_model, ξ0, total_time/n_leapfrog, n_leapfrog, T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
    filename  = "/xtmp/GZZ_data/mixed_effects/GibbsHMC:d:"*
                string(d)*"-n_groups:"*string(n_groups)*"-Nobs:"*string(Nobs)*
                "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog)*".jld"
    save(filename, "xi_samples", xi_samples_hmc, "hyper_samples", hyper_samples_hmc, "acc", acc)
    xi_samples_hmc, hyper_samples_hmc, acc = [], [], []
    gc()
end
# Out:
# HMC acceptance = 62.26 percent; n_leapfrog = 23 in 2.69 mins
# HMC acceptance = 65.06 percent; n_leapfrog = 27 in 3.0 mins
# HMC acceptance = 72.18 percent; n_leapfrog = 32 in 3.53 mins
# HMC acceptance = 71.0 percent; n_leapfrog = 36 in 3.79 mins
# HMC acceptance = 70.44 percent; n_leapfrog = 40 in 4.21 mins
# HMC acceptance = 62.88 percent; n_leapfrog = 43 in 4.43 mins
# HMC acceptance = 63.6 percent; n_leapfrog = 47 in 4.85 mins
# HMC acceptance = 62.5 percent; n_leapfrog = 51 in 5.28 mins
# HMC acceptance = 52.18 percent; n_leapfrog = 52 in 5.41 mins
# HMC acceptance = 68.26 percent; n_leapfrog = 60 in 6.24 mins

# %%
maxlag_hmc = 50
fig = figure(figsize=(12,4))
acfs_hmc = zeros(length(total_times_optimal),dim_total,maxlag_hmc)

for i in 1:2 
    for j in 1:5
        k = 5*(i-1)+j
        total_time, n_leapfrog = total_times_optimal[k], n_leapfrog_optimal[k]
        filename  = "/xtmp/GZZ_data/mixed_effects/GibbsHMC:d:"*
                string(d)*"-n_groups:"*string(n_groups)*"-Nobs:"*string(Nobs)*
                "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog)*".jld"
        xi_samples_hmc = load(filename, "xi_samples")

        subplot(2,5,k)
        for dim in 1:size(xi_samples_hmc,1) 
            a = acf(xi_samples_hmc[dim,:], maxlag_hmc)
            plot(a)
            acfs_hmc[k,dim,:] = a
        end
        grid(true)  
        title("Total time:"*string(total_time)*", \n n_leapfrog:"*string(n_leapfrog), fontsize=10)
        xi_samples_hmc = []
        gc()
        if i == 2 xlabel("Lag") end
        if j == 1 ylabel("ACF") end
        subplots_adjust(hspace=0.5)
    end
end
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x400 with 10 Axes>)

# %%
T = 5000
maxlag_hmc_list = [10, 10, 20, 15, 15, 15, 40, 40, 15, 20]
hmc_mixing = zeros(length(total_times_optimal))
for i in 1:length(total_times_optimal)
    hmc_mixing[i] = T/maximum(sum(acfs_hmc[i,:,1:maxlag_hmc_list[i]],2))
end
hmc_cost = T*n_leapfrog_optimal*Nobs;

# %%
gzz_mixing = n_samples/maximum(sum(acfs_gzz[:,1:100],2))
gzz_cost = max_attempts*mb_size
minimum((gzz_mixing/gzz_cost)./(hmc_mixing./hmc_cost))
# Out:
# 2.6096167173914098

# %%
(gzz_mixing/gzz_cost)./(hmc_mixing./hmc_cost)
# Out:
# 10-element Array{Float64,1}:
#   2.65966
#   2.60962
#   9.42178
#  10.4415
#   7.25493
#   7.71768
#  15.568
#  17.7653
#   6.23961
#   8.52595
