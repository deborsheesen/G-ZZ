# %%
using Distributions, TimeIt, ProgressMeter, PyPlot, JLD
include("/home/postdoc/dsen/Desktop/codes/G-ZZ_clean/jl_files/zz_samplers.jl")
include("temp.jl")
# Out:
# run_sampler (generic function with 4 methods)

# %% [raw]
# d, Nobs = 51, 250
# pX = 1e-1
# pξ = 1e-1
# X = sprandn(d, Nobs, pX)
# X[1,:] = 1
# ξ_true = sprandn(d, pξ)
# y = Float64.([rand(Binomial(1, 1/(1+exp(-ξ_true'X[:,j])))) for j in 1:Nobs])
# save("shrinkage_data_1.jld", "X", X, "y", y)

# %%
X, y = load("shrinkage_data_1.jld", "X", "y")
d, Nobs = size(X)
σ02 = 1
my_pr = SS_prior(d, σ02)
my_ll = ll_logistic_sp(X,y)
my_model = model(my_ll, my_pr);

# %% [markdown]
# ### GZZ:

# %%
# Sub-sampling without control variates and with weights:
mb_size = 1
max_attempts = 2*10^6
lambda = 5e1
Print = true;

# %%
start = time()
run_sampler(my_model, lambda, max_attempts, mb_size, Print) 
print("Sampling in ", round((time()-start)/60,1), " mins \n")
# Out:
# 10 percent attempts in 2.47 min; zz bounces = 39660, hyp bounces = 7289, total time of process = 143.309
# 20 percent attempts in 5.11 min; zz bounces = 79675, hyp bounces = 14380, total time of process = 286.281
# 30 percent attempts in 7.84 min; zz bounces = 119123, hyp bounces = 21509, total time of process = 430.142
# 40 percent attempts in 10.65 min; zz bounces = 159813, hyp bounces = 28586, total time of process = 573.161
# 50 percent attempts in 13.44 min; zz bounces = 199527, hyp bounces = 35673, total time of process = 716.454
# 60 percent attempts in 16.24 min; zz bounces = 238911, hyp bounces = 42899, total time of process = 859.669
# 70 percent attempts in 19.02 min; zz bounces = 278687, hyp bounces = 50197, total time of process = 1003.471
# 80 percent attempts in 21.81 min; zz bounces = 317767, hyp bounces = 57504, total time of process = 1146.641
# 90 percent attempts in 24.67 min; zz bounces = 357785, hyp bounces = 64700, total time of process = 1289.742
# 100 percent attempts in 27.49 min; zz bounces = 397496, hyp bounces = 71891, total time of process = 1432.909
# Sampling in 27.5 mins

# %%
fig = figure("pyplot_barplot",figsize=(5,3))
n_samples = 10^4
maxlag_gzz = 500
acfs_gzz = zeros(d,maxlag_gzz)
discard = 0
filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/lambda:"*string(lambda)*
            "-d:"*string(d)*"-Nobs:"*string(Nobs)*"-mb_size:"*string(mb_size)*".jld"
xt_skel, bt_skel = load(filename, "xt_skeleton", "bt_skeleton")
xi_samples_gzz = extract_samples(xt_skel[:,discard+1:end], 
                             bt_skel[:,discard+1:end], 
                            (bt_skel[end]-bt_skel[discard+1])/n_samples,
                            "linear")[:,1:end-1]
iacts_gzz = zeros(size(xi_samples_gzz,1))
for dim in 1:size(xi_samples_gzz,1)
    a = acf(xi_samples_gzz[dim,:],maxlag_gzz)
    plot(a)
    acfs_gzz[dim,:] = a
end
title("ACFs for GZZ")
xlabel("Lag")
ylabel("ACF")
grid(true)
xt_skel, bt_skel, xi_samples = [], [], []
gc()
# Out:
# PyPlot.Figure(PyObject <Figure size 500x300 with 1 Axes>)

# %% [markdown]
# ### HMC:

# %% [markdown]
# ### Tune HMC:

# %%
ξ0 = randn(d)
Total_time = 10
T = 250
Metropolise = false
Print = false
n_leapfrog_list = 20*(1:5);

# %%
prior = SS_prior(d, σ02)
xi_samples_hmc, hyper_samples_hmc, acc = 
zeros(d,T+1,length(n_leapfrog_list)), zeros(hyperparam_size(prior),T+1,length(n_leapfrog_list)), 
zeros(length(n_leapfrog_list));

# %%
for (i,n_leapfrog) in enumerate(reverse(n_leapfrog_list))
    start = time()
    prior = SS_prior(d, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    stepsize = Total_time/n_leapfrog
    xi_samples_hmc[:,:,i], hyper_samples_hmc[:,:,i], acc[i] = 
    GibbsHMC(my_model, ξ0, stepsize, n_leapfrog, T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
end
# Out:
# HMC acceptance = 100.0 percent; n_leapfrog = 100 in 1.44 mins
# HMC acceptance = 100.0 percent; n_leapfrog = 80 in 1.15 mins
# HMC acceptance = 100.0 percent; n_leapfrog = 60 in 0.87 mins
# ArgumentError: InverseGamma: the condition α > zero(α) && θ > zero(θ) is not satisfied.
#
# Stacktrace:
#  [1] macro expansion at /home/postdoc/dsen/.julia/v0.6/Distributions/src/utils.jl:6 [inlined]
#  [2] Distributions.InverseGamma{Float64}(::Float64, ::Float64) at /home/postdoc/dsen/.julia/v0.6/Distributions/src/univariate/continuous/inversegamma.jl:33
#  [3] (::##505#511{SS_prior,Array{Float64,1}})(::Int64) at ./<missing>:0
#  [4] collect(::Base.Generator{UnitRange{Int64},##505#511{SS_prior,Array{Float64,1}}}) at ./array.jl:470
#  [5] block_Gibbs_update_hyperparams(::SS_prior, ::Array{Float64,1}) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/priors.jl:153
#  [6] GibbsHMC(::model, ::Array{Float64,1}, ::Float64, ::Int64, ::Int64, ::Bool, ::Bool) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl:632
#  [7] macro expansion at ./In[18]:7 [inlined]
#  [8] anonymous at ./<missing>:?
#  [9] include_string(::String, ::String) at ./loading.jl:522

# %%
Metropolise = true 
Print = false

stepsize = Total_time/50
total_times = 5*stepsize*(5:15)
n_leapfrog_steps = 5*(1:10)

for total_time in total_times
    print("Total time = ", round(total_time,2), "\n")
    for n_leapfrog in n_leapfrog_steps
        start = time()
        prior = SS_prior(d, σ02)
        my_ll = ll_logistic_sp(X,y)
        my_model = model(my_ll, prior)
        a, b, c = 
        GibbsHMC(my_model, ξ0, total_time/n_leapfrog, n_leapfrog, 500, Metropolise, Print)
        print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
    end
end
# Out:
# Total time = 5.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.17 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 10 in 0.31 mins
# HMC acceptance = 1.0 percent; n_leapfrog = 15 in 0.45 mins
# HMC acceptance = 42.2 percent; n_leapfrog = 20 in 0.59 mins
# HMC acceptance = 68.0 percent; n_leapfrog = 25 in 0.73 mins
# HMC acceptance = 82.4 percent; n_leapfrog = 30 in 0.87 mins
# HMC acceptance = 84.2 percent; n_leapfrog = 35 in 1.01 mins
# HMC acceptance = 89.2 percent; n_leapfrog = 40 in 1.15 mins
# HMC acceptance = 91.4 percent; n_leapfrog = 45 in 1.31 mins
# HMC acceptance = 92.2 percent; n_leapfrog = 50 in 1.44 mins
# Total time = 6.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.17 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.31 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 15 in 0.45 mins
# HMC acceptance = 2.6 percent; n_leapfrog = 20 in 0.59 mins
# HMC acceptance = 50.2 percent; n_leapfrog = 25 in 0.73 mins
# HMC acceptance = 71.6 percent; n_leapfrog = 30 in 0.88 mins
# HMC acceptance = 78.6 percent; n_leapfrog = 35 in 1.03 mins
# HMC acceptance = 81.0 percent; n_leapfrog = 40 in 1.16 mins
# HMC acceptance = 86.2 percent; n_leapfrog = 45 in 1.3 mins
# HMC acceptance = 90.6 percent; n_leapfrog = 50 in 1.44 mins
# Total time = 7.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.17 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.31 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 15 in 0.46 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 20 in 0.61 mins
# HMC acceptance = 18.8 percent; n_leapfrog = 25 in 0.76 mins
# HMC acceptance = 61.8 percent; n_leapfrog = 30 in 0.9 mins
# HMC acceptance = 70.6 percent; n_leapfrog = 35 in 1.05 mins
# HMC acceptance = 75.8 percent; n_leapfrog = 40 in 1.19 mins
# HMC acceptance = 82.6 percent; n_leapfrog = 45 in 1.3 mins
# HMC acceptance = 86.4 percent; n_leapfrog = 50 in 1.44 mins
# Total time = 8.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.17 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.31 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.46 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 20 in 0.6 mins
# HMC acceptance = 0.8 percent; n_leapfrog = 25 in 0.74 mins
# HMC acceptance = 26.8 percent; n_leapfrog = 30 in 0.88 mins
# HMC acceptance = 58.2 percent; n_leapfrog = 35 in 1.01 mins
# HMC acceptance = 70.4 percent; n_leapfrog = 40 in 1.15 mins
# HMC acceptance = 76.6 percent; n_leapfrog = 45 in 1.29 mins
# HMC acceptance = 78.8 percent; n_leapfrog = 50 in 1.44 mins
# Total time = 9.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.17 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.31 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.46 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 20 in 0.59 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 25 in 0.74 mins
# HMC acceptance = 2.2 percent; n_leapfrog = 30 in 0.88 mins
# HMC acceptance = 36.0 percent; n_leapfrog = 35 in 1.02 mins
# HMC acceptance = 58.4 percent; n_leapfrog = 40 in 1.17 mins
# HMC acceptance = 70.0 percent; n_leapfrog = 45 in 1.3 mins
# HMC acceptance = 74.2 percent; n_leapfrog = 50 in 1.44 mins
# Total time = 10.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.17 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.31 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.46 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 20 in 0.59 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 25 in 0.74 mins
# HMC acceptance = 0.8 percent; n_leapfrog = 30 in 0.88 mins
# HMC acceptance = 9.6 percent; n_leapfrog = 35 in 1.02 mins
# HMC acceptance = 40.0 percent; n_leapfrog = 40 in 1.16 mins
# HMC acceptance = 60.0 percent; n_leapfrog = 45 in 1.3 mins
# HMC acceptance = 70.6 percent; n_leapfrog = 50 in 1.44 mins
# Total time = 11.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.17 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.31 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.46 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.59 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.74 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 30 in 0.88 mins
# HMC acceptance = 0.8 percent; n_leapfrog = 35 in 1.03 mins
# HMC acceptance = 19.8 percent; n_leapfrog = 40 in 1.16 mins
# HMC acceptance = 46.0 percent; n_leapfrog = 45 in 1.29 mins
# HMC acceptance = 60.4 percent; n_leapfrog = 50 in 1.44 mins
# Total time = 12.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.17 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.31 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.46 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.59 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.73 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 30 in 0.87 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 35 in 1.01 mins
# HMC acceptance = 1.8 percent; n_leapfrog = 40 in 1.16 mins
# HMC acceptance = 36.4 percent; n_leapfrog = 45 in 1.3 mins
# HMC acceptance = 48.6 percent; n_leapfrog = 50 in 1.44 mins
# Total time = 13.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.17 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.32 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.46 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.6 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.74 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 30 in 0.9 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 35 in 1.03 mins
# HMC acceptance = 1.0 percent; n_leapfrog = 40 in 1.17 mins
# HMC acceptance = 4.4 percent; n_leapfrog = 45 in 1.32 mins
# HMC acceptance = 37.6 percent; n_leapfrog = 50 in 1.46 mins
# Total time = 14.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.17 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.32 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.46 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.6 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.74 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 0.89 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 35 in 1.03 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 40 in 1.17 mins
# HMC acceptance = 1.2 percent; n_leapfrog = 45 in 1.31 mins
# HMC acceptance = 9.8 percent; n_leapfrog = 50 in 1.45 mins
# Total time = 15.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.17 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.31 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.45 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.6 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.75 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 0.88 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 35 in 1.02 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 40 in 1.16 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 45 in 1.31 mins
# HMC acceptance = 1.6 percent; n_leapfrog = 50 in 1.45 mins

# %%
total_times_optimal = 5:11
n_leapfrog_optimal = [25,28,32,38,43,48,53]
T = 5000
Metropolise = true
Print = false

for (i,total_time) in enumerate(total_times_optimal) 
    start = time()
    prior = SS_prior(d, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    xi_samples_hmc, hyper_samples_hmc, acc =
    GibbsHMC(my_model, ξ0, total_time/n_leapfrog_optimal[i], n_leapfrog_optimal[i], T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog_optimal[i], " in ", round((time()-start)/60,2), " mins \n")
    filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/GibbsHMC:d:"*string(d)*"-Nobs:"*string(Nobs)*
                "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog_optimal[i])*".jld"
    save(filename, "xi_samples", xi_samples_hmc, "hyper_samples", hyper_samples_hmc, "acc", acc)
    xi_samples_hmc, hyper_samples_hmc, acc = [], [], []
    gc()
end
# Out:
# HMC acceptance = 68.56 percent; n_leapfrog = 25 in 7.26 mins
# HMC acceptance = 61.68 percent; n_leapfrog = 28 in 8.08 mins
# HMC acceptance = 60.28 percent; n_leapfrog = 32 in 9.17 mins
# HMC acceptance = 64.94 percent; n_leapfrog = 38 in 10.87 mins
# HMC acceptance = 66.84 percent; n_leapfrog = 43 in 12.3 mins
# HMC acceptance = 64.92 percent; n_leapfrog = 48 in 13.7 mins
# HMC acceptance = 65.94 percent; n_leapfrog = 53 in 15.42 mins

# %%
maxlag_hmc = 40
fig = figure(figsize=(12,4))
acfs_hmc = zeros(length(total_times_optimal),size(xi_samples_hmc,1),maxlag_hmc)

for i in 1:2 
    for j in 1:4
        k = 4*(i-1)+j
        if k < 8
            total_time, n_leapfrog = total_times_optimal[k], n_leapfrog_optimal[k]
            filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/GibbsHMC:d:"*string(d)*"-Nobs:"*string(Nobs)*
                "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog)*".jld"
            xi_samples_hmc = load(filename, "xi_samples")

            subplot(2,4,k)
            for dim in 1:size(xi_samples_hmc,1) 
                a = acf(xi_samples_hmc[dim,:], maxlag_hmc)
                plot(a)
                acfs_hmc[k,dim,:] = a
            end
            grid(true)  
            title("Total time:"*string(total_time)*", n_leapfrog:"*string(n_leapfrog), fontsize=10)
            xi_samples_hmc = []
            gc()
            if i == 2 xlabel("Lag") end
            if i == 1 xticks(alpha=0) end
            if j == 1 ylabel("ACF") end
        end
    end
end
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x400 with 7 Axes>)

# %%
hmc_mixing = T./maximum(sum(acfs_hmc[:,:,1:10],3),2)
hmc_cost = T*n_leapfrog_optimal*Nobs;

# %%
gzz_mixing = n_samples/maximum(sum(acfs_gzz[:,1:100],2))
gzz_cost = max_attempts*mb_size;

# %%
(gzz_mixing/gzz_cost)./(hmc_mixing./hmc_cost)
# Out:
# 7×1×1 Array{Float64,3}:
# [:, :, 1] =
#  2.04358
#  2.9388
#  3.58199
#  3.98361
#  3.90141
#  3.89648
#  4.17978
