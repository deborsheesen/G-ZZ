# %%
using Distributions, TimeIt, ProgressMeter, PyPlot, JLD
include("/home/postdoc/dsen/Desktop/codes/G-ZZ_clean/jl_files/zz_samplers.jl")
include("temp.jl")
# Out:
# run_sampler (generic function with 4 methods)

# %% [raw]
# d, Nobs = 100, 1000
# pX = 5e-2
# pξ = 1e-1
# X = sprandn(d, Nobs, pX)
# X[1,:] = 1
# ξ_true = sprandn(d, pξ)
# y = Float64.([rand(Binomial(1, 1/(1+exp(-ξ_true'X[:,j])))) for j in 1:Nobs])
# save("shrinkage_data_2.jld", "X", X, "y", y)

# %%
X, y = load("shrinkage_data_2.jld", "X", "y")
d, Nobs = size(X)
σ02 = 1
my_pr = SS_prior(d, σ02)
my_ll = ll_logistic_sp(X,y)
my_model = model(my_ll, my_pr);

# %% [markdown]
# ### GZZ:

# %%
# Sub-sampling without control variates and with weights:
mb_size = 1
max_attempts = 5*10^6
lambda = 2e1
Print = true;

# %%
start = time()
run_sampler(my_model, lambda, max_attempts, mb_size, Print) 
print("Sampling in ", round((time()-start)/60,1), " mins \n")
# Out:
# 10 percent attempts in 7.03 min; zz bounces = 114347, hyp bounces = 1808, total time of process = 93.858
# 20 percent attempts in 14.40 min; zz bounces = 229085, hyp bounces = 3680, total time of process = 187.384
# 30 percent attempts in 21.62 min; zz bounces = 343364, hyp bounces = 5577, total time of process = 281.206
# 40 percent attempts in 29.00 min; zz bounces = 458505, hyp bounces = 7509, total time of process = 375.002
# 50 percent attempts in 36.42 min; zz bounces = 572692, hyp bounces = 9330, total time of process = 469.011
# 60 percent attempts in 44.07 min; zz bounces = 687653, hyp bounces = 11241, total time of process = 562.913
# 70 percent attempts in 51.79 min; zz bounces = 801883, hyp bounces = 13184, total time of process = 656.796
# 80 percent attempts in 59.72 min; zz bounces = 916650, hyp bounces = 15084, total time of process = 750.749
# 90 percent attempts in 67.67 min; zz bounces = 1031755, hyp bounces = 16955, total time of process = 844.540
# 100 percent attempts in 75.80 min; zz bounces = 1146645, hyp bounces = 18853, total time of process = 938.528
# Sampling in 76.0 mins

# %%
fig = figure("pyplot_barplot",figsize=(5,3))
n_samples = 10^4
maxlag_gzz = 500
acfs_gzz = zeros(d,maxlag_gzz)
discard = 0
filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/lambda:"*string(lambda)*
            "-d:"*string(d)*"-Nobs:"*string(Nobs)*"-mb_size:"*string(mb_size)*".jld"
xt_skel, bt_skel = load(filename, "xt_skeleton", "bt_skeleton")
xi_samples_gzz = extract_samples(xt_skel[:,discard+1:end], 
                             bt_skel[:,discard+1:end], 
                            (bt_skel[end]-bt_skel[discard+1])/n_samples,
                            "linear")[:,1:end-1]
iacts_gzz = zeros(size(xi_samples_gzz,1))
for dim in 1:size(xi_samples_gzz,1)
    a = acf(xi_samples_gzz[dim,:],maxlag_gzz)
    plot(a)
    acfs_gzz[dim,:] = a
end
title("ACFs for GZZ")
xlabel("Lag")
ylabel("ACF")
grid(true)
xt_skel, bt_skel, xi_samples = [], [], []
gc()
# Out:
# PyPlot.Figure(PyObject <Figure size 500x300 with 1 Axes>)
