# %%
using Distributions, TimeIt, ProgressMeter, PyPlot, JLD
include("/home/postdoc/dsen/Desktop/codes/G-ZZ_clean/jl_files/zz_samplers.jl")
include("temp.jl")
# Out:
# run_sampler (generic function with 4 methods)

# %% [raw]
# d, Nobs = 101, 1000
# pX = 50/Nobs
# pξ = 1e-1
# X = sprandn(d, Nobs, pX)
# X[1,:] = 1
# ξ_true = sprandn(d, pξ)
# y = Float64.([rand(Binomial(1, 1/(1+exp(-ξ_true'X[:,j])))) for j in 1:Nobs])
# save("shrinkage_data_2.10.jld", "X", X, "y", y)

# %%
X, y = load("shrinkage_data_2.10.jld", "X", "y")
d, Nobs = size(X)
σ02 = 1
my_pr = SS_prior(d, σ02)
my_ll = ll_logistic_sp(X,y)
my_model = model(my_ll, my_pr)
print("d = ",  d, ", N = ", Nobs)
# Out:
# d = 101, N = 1000

# %% [markdown]
# ### GZZ:

# %%
# Sub-sampling without control variates and with weights:
mb_size = 1
max_attempts = 10^7
lambda = 2e1
Print = true;

# %%
start = time()
run_sampler(my_model, lambda, max_attempts, mb_size, Print) 
print("Sampling in ", round((time()-start)/60,1), " mins \n")
# Out:
# 10 percent attempts in 67.87 min; zz bounces = 237039, hyp bounces = 3716, total time of process = 182.371
# 20 percent attempts in 137.60 min; zz bounces = 474523, hyp bounces = 7404, total time of process = 365.013
# 30 percent attempts in 208.20 min; zz bounces = 711930, hyp bounces = 11104, total time of process = 547.384
# 40 percent attempts in 278.42 min; zz bounces = 949494, hyp bounces = 14701, total time of process = 729.744
# 50 percent attempts in 347.33 min; zz bounces = 1187167, hyp bounces = 18302, total time of process = 912.390
# 60 percent attempts in 416.37 min; zz bounces = 1424409, hyp bounces = 21889, total time of process = 1095.058
# 70 percent attempts in 506.20 min; zz bounces = 1661299, hyp bounces = 25516, total time of process = 1277.944
# 80 percent attempts in 734.17 min; zz bounces = 1898267, hyp bounces = 29128, total time of process = 1460.528
# 90 percent attempts in 796.05 min; zz bounces = 2135849, hyp bounces = 32799, total time of process = 1642.763
# 100 percent attempts in 828.02 min; zz bounces = 2372674, hyp bounces = 36486, total time of process = 1825.237
# Sampling in 828.3 mins

# %%
fig = figure("pyplot_barplot",figsize=(5,3))
n_samples = 10^4
maxlag_gzz = 500
acfs_gzz = zeros(d,maxlag_gzz)
discard = 0
filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/lambda:"*string(lambda)*
            "-d:"*string(d)*"-Nobs:"*string(Nobs)*"-mb_size:"*string(mb_size)*".jld"
xt_skel, bt_skel = load(filename, "xt_skeleton", "bt_skeleton")
xi_samples_gzz = extract_samples(xt_skel[:,discard+1:end], 
                             bt_skel[:,discard+1:end], 
                            (bt_skel[end]-bt_skel[discard+1])/n_samples,
                            "linear")[:,1:end-1]
iacts_gzz = zeros(size(xi_samples_gzz,1))
for dim in 1:size(xi_samples_gzz,1)
    a = acf(xi_samples_gzz[dim,:],maxlag_gzz)
    plot(a)
    acfs_gzz[dim,:] = a
end
title("ACFs for GZZ")
xlabel("Lag")
ylabel("ACF")
grid(true)
xt_skel, bt_skel, xi_samples = [], [], []
gc()
# Out:
# PyPlot.Figure(PyObject <Figure size 500x300 with 1 Axes>)
