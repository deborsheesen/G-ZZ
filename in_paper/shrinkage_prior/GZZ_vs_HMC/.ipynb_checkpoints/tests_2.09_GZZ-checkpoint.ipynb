# %%
using Distributions, TimeIt, ProgressMeter, PyPlot, JLD
include("/home/postdoc/dsen/Desktop/codes/G-ZZ_clean/jl_files/zz_samplers.jl")
include("temp.jl")
# Out:
# run_sampler (generic function with 4 methods)

# %% [raw]
# d, Nobs = 101, 900
# pX = 50/Nobs
# pξ = 1e-1
# X = sprandn(d, Nobs, pX)
# X[1,:] = 1
# ξ_true = sprandn(d, pξ)
# y = Float64.([rand(Binomial(1, 1/(1+exp(-ξ_true'X[:,j])))) for j in 1:Nobs])
# save("shrinkage_data_2.9.jld", "X", X, "y", y)

# %%
X, y = load("shrinkage_data_2.9.jld", "X", "y")
d, Nobs = size(X)
σ02 = 1
my_pr = SS_prior(d, σ02)
my_ll = ll_logistic_sp(X,y)
my_model = model(my_ll, my_pr)
print("d = ",  d, ", N = ", Nobs)
# Out:
# d = 101, N = 900

# %% [markdown]
# ### GZZ:

# %%
# Sub-sampling without control variates and with weights:
mb_size = 1
max_attempts = 10^7
lambda = 2e1
Print = true;

# %%
start = time()
run_sampler(my_model, lambda, max_attempts, mb_size, Print) 
print("Sampling in ", round((time()-start)/60,1), " mins \n")
# Out:
# 10 percent attempts in 66.90 min; zz bounces = 227222, hyp bounces = 3805, total time of process = 190.616
# 20 percent attempts in 135.59 min; zz bounces = 456243, hyp bounces = 7614, total time of process = 381.309
# 30 percent attempts in 204.67 min; zz bounces = 684765, hyp bounces = 11372, total time of process = 572.150
# 40 percent attempts in 274.22 min; zz bounces = 911955, hyp bounces = 15178, total time of process = 762.625
# 50 percent attempts in 342.22 min; zz bounces = 1141509, hyp bounces = 18951, total time of process = 952.889
# 60 percent attempts in 416.14 min; zz bounces = 1369668, hyp bounces = 22818, total time of process = 1143.556
# 70 percent attempts in 503.90 min; zz bounces = 1596807, hyp bounces = 26617, total time of process = 1334.363
# 80 percent attempts in 584.19 min; zz bounces = 1825607, hyp bounces = 30420, total time of process = 1524.971
# 90 percent attempts in 654.67 min; zz bounces = 2054695, hyp bounces = 34274, total time of process = 1715.392
# 100 percent attempts in 728.90 min; zz bounces = 2284199, hyp bounces = 37997, total time of process = 1905.858
# Sampling in 729.6 mins

# %%
fig = figure("pyplot_barplot",figsize=(5,3))
n_samples = 10^4
maxlag_gzz = 500
acfs_gzz = zeros(d,maxlag_gzz)
discard = 0
filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/lambda:"*string(lambda)*
            "-d:"*string(d)*"-Nobs:"*string(Nobs)*"-mb_size:"*string(mb_size)*".jld"
xt_skel, bt_skel = load(filename, "xt_skeleton", "bt_skeleton")
xi_samples_gzz = extract_samples(xt_skel[:,discard+1:end], 
                             bt_skel[:,discard+1:end], 
                            (bt_skel[end]-bt_skel[discard+1])/n_samples,
                            "linear")[:,1:end-1]
iacts_gzz = zeros(size(xi_samples_gzz,1))
for dim in 1:size(xi_samples_gzz,1)
    a = acf(xi_samples_gzz[dim,:],maxlag_gzz)
    plot(a)
    acfs_gzz[dim,:] = a
end
title("ACFs for GZZ")
xlabel("Lag")
ylabel("ACF")
grid(true)
xt_skel, bt_skel, xi_samples = [], [], []
gc()
# Out:
# PyPlot.Figure(PyObject <Figure size 500x300 with 1 Axes>)
