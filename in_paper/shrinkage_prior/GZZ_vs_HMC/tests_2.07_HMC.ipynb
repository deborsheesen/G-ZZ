# %%
using Distributions, TimeIt, ProgressMeter, PyPlot, JLD
include("/home/postdoc/dsen/Desktop/codes/G-ZZ_clean/jl_files/zz_samplers.jl")
include("temp.jl")
# Out:
# run_sampler (generic function with 4 methods)

# %%
X, y = load("shrinkage_data_2.7.jld", "X", "y")
d, Nobs = size(X)
σ02 = 1
my_pr = SS_prior(d, σ02)
my_ll = ll_logistic_sp(X,y)
my_model = model(my_ll, my_pr)
print("d = ",  d, ", N = ", Nobs)
# Out:
# d = 101, N = 700

# %% [markdown]
# ### HMC:

# %% [markdown]
# ### Tune HMC:

# %%
ξ0 = randn(d)
Total_time = 10
T = 250
Metropolise = false
Print = false
n_leapfrog_list = 20*(1:5)
prior = SS_prior(d, σ02);

# %%
xi_samples_hmc, hyper_samples_hmc, acc = 
zeros(d,T+1,length(n_leapfrog_list)), zeros(hyperparam_size(prior),T+1,length(n_leapfrog_list)), 
zeros(length(n_leapfrog_list));

# %%
for (i,n_leapfrog) in enumerate(reverse(n_leapfrog_list))
    start = time()
    prior = SS_prior(d, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    stepsize = Total_time/n_leapfrog
    xi_samples_hmc[:,:,i], hyper_samples_hmc[:,:,i], acc[i] = 
    GibbsHMC(my_model, ξ0, stepsize, n_leapfrog, T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
end
# Out:
# HMC acceptance = 100.0 percent; n_leapfrog = 100 in 3.93 mins
# HMC acceptance = 100.0 percent; n_leapfrog = 80 in 3.18 mins
# HMC acceptance = 100.0 percent; n_leapfrog = 60 in 2.39 mins
# ArgumentError: InverseGamma: the condition α > zero(α) && θ > zero(θ) is not satisfied.
#
# Stacktrace:
#  [1] macro expansion at /home/postdoc/dsen/.julia/v0.6/Distributions/src/utils.jl:6 [inlined]
#  [2] Distributions.InverseGamma{Float64}(::Float64, ::Float64) at /home/postdoc/dsen/.julia/v0.6/Distributions/src/univariate/continuous/inversegamma.jl:33
#  [3] (::##505#511{SS_prior,Array{Float64,1}})(::Int64) at ./<missing>:0
#  [4] collect(::Base.Generator{UnitRange{Int64},##505#511{SS_prior,Array{Float64,1}}}) at ./array.jl:470
#  [5] block_Gibbs_update_hyperparams(::SS_prior, ::Array{Float64,1}) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/priors.jl:152
#  [6] GibbsHMC(::model, ::Array{Float64,1}, ::Float64, ::Int64, ::Int64, ::Bool, ::Bool) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl:634
#  [7] macro expansion at ./In[5]:7 [inlined]
#  [8] anonymous at ./<missing>:?
#  [9] include_string(::String, ::String) at ./loading.jl:522

# %%
Metropolise = true 
Print = false

stepsize = Total_time/50
total_times = 2.2*stepsize*(5:15)
n_leapfrog_steps = 5*(1:10)

for total_time in total_times
    print("Total time = ", round(total_time,2), "\n")
    for n_leapfrog in n_leapfrog_steps
        start = time()
        prior = SS_prior(d, σ02)
        my_ll = ll_logistic_sp(X,y)
        my_model = model(my_ll, prior)
        a, b, c = 
        GibbsHMC(my_model, ξ0, total_time/n_leapfrog, n_leapfrog, 500, Metropolise, Print)
        print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
    end
end
# Out:
# Total time = 2.2
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.45 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.86 mins
# HMC acceptance = 51.2 percent; n_leapfrog = 15 in 1.24 mins
# HMC acceptance = 74.0 percent; n_leapfrog = 20 in 1.64 mins
# HMC acceptance = 85.6 percent; n_leapfrog = 25 in 2.1 mins
# HMC acceptance = 90.0 percent; n_leapfrog = 30 in 2.41 mins
# HMC acceptance = 93.0 percent; n_leapfrog = 35 in 2.75 mins
# HMC acceptance = 94.6 percent; n_leapfrog = 40 in 3.04 mins
# HMC acceptance = 93.6 percent; n_leapfrog = 45 in 3.43 mins
# HMC acceptance = 95.6 percent; n_leapfrog = 50 in 3.91 mins
# Total time = 2.64
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.45 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.82 mins
# HMC acceptance = 1.8 percent; n_leapfrog = 15 in 1.18 mins
# HMC acceptance = 62.2 percent; n_leapfrog = 20 in 1.54 mins
# HMC acceptance = 79.6 percent; n_leapfrog = 25 in 1.91 mins
# HMC acceptance = 84.0 percent; n_leapfrog = 30 in 2.39 mins
# HMC acceptance = 85.2 percent; n_leapfrog = 35 in 2.75 mins
# HMC acceptance = 90.6 percent; n_leapfrog = 40 in 3.04 mins
# HMC acceptance = 95.4 percent; n_leapfrog = 45 in 3.43 mins
# HMC acceptance = 95.4 percent; n_leapfrog = 50 in 3.76 mins
# Total time = 3.08
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.45 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.81 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.21 mins
# HMC acceptance = 39.0 percent; n_leapfrog = 20 in 1.6 mins
# HMC acceptance = 64.4 percent; n_leapfrog = 25 in 1.97 mins
# HMC acceptance = 77.4 percent; n_leapfrog = 30 in 2.35 mins
# HMC acceptance = 82.8 percent; n_leapfrog = 35 in 2.73 mins
# HMC acceptance = 85.6 percent; n_leapfrog = 40 in 3.14 mins
# HMC acceptance = 87.0 percent; n_leapfrog = 45 in 3.52 mins
# HMC acceptance = 93.8 percent; n_leapfrog = 50 in 3.81 mins
# Total time = 3.52
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.45 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.81 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.18 mins
# HMC acceptance = 1.0 percent; n_leapfrog = 20 in 1.63 mins
# HMC acceptance = 53.4 percent; n_leapfrog = 25 in 1.93 mins
# HMC acceptance = 70.2 percent; n_leapfrog = 30 in 2.29 mins
# HMC acceptance = 79.4 percent; n_leapfrog = 35 in 2.65 mins
# HMC acceptance = 82.4 percent; n_leapfrog = 40 in 3.17 mins
# HMC acceptance = 88.6 percent; n_leapfrog = 45 in 3.56 mins
# HMC acceptance = 90.0 percent; n_leapfrog = 50 in 3.84 mins
# Total time = 3.96
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.48 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.83 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.24 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 20 in 1.57 mins
# HMC acceptance = 34.6 percent; n_leapfrog = 25 in 1.91 mins
# HMC acceptance = 64.0 percent; n_leapfrog = 30 in 2.31 mins
# HMC acceptance = 72.2 percent; n_leapfrog = 35 in 2.65 mins
# HMC acceptance = 78.2 percent; n_leapfrog = 40 in 3.01 mins
# HMC acceptance = 83.0 percent; n_leapfrog = 45 in 3.38 mins
# HMC acceptance = 89.6 percent; n_leapfrog = 50 in 3.74 mins
# Total time = 4.4
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.44 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.82 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.18 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.54 mins
# HMC acceptance = 1.4 percent; n_leapfrog = 25 in 1.95 mins
# HMC acceptance = 46.2 percent; n_leapfrog = 30 in 2.37 mins
# HMC acceptance = 68.0 percent; n_leapfrog = 35 in 2.69 mins
# HMC acceptance = 71.2 percent; n_leapfrog = 40 in 3.07 mins
# HMC acceptance = 77.8 percent; n_leapfrog = 45 in 3.57 mins
# HMC acceptance = 85.2 percent; n_leapfrog = 50 in 4.05 mins
# Total time = 4.84
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.45 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.82 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.2 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.57 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 25 in 1.96 mins
# HMC acceptance = 26.2 percent; n_leapfrog = 30 in 2.42 mins
# HMC acceptance = 58.8 percent; n_leapfrog = 35 in 2.77 mins
# HMC acceptance = 68.8 percent; n_leapfrog = 40 in 3.07 mins
# HMC acceptance = 75.0 percent; n_leapfrog = 45 in 3.51 mins
# HMC acceptance = 82.4 percent; n_leapfrog = 50 in 3.96 mins
# Total time = 5.28
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.45 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.83 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.2 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.58 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 2.04 mins
# HMC acceptance = 1.4 percent; n_leapfrog = 30 in 2.5 mins
# HMC acceptance = 39.6 percent; n_leapfrog = 35 in 2.91 mins
# HMC acceptance = 61.2 percent; n_leapfrog = 40 in 3.28 mins
# HMC acceptance = 72.0 percent; n_leapfrog = 45 in 3.56 mins
# HMC acceptance = 79.2 percent; n_leapfrog = 50 in 3.99 mins
# Total time = 5.72
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.45 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.83 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.2 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.58 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.96 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 30 in 2.34 mins
# HMC acceptance = 15.8 percent; n_leapfrog = 35 in 2.74 mins
# HMC acceptance = 55.2 percent; n_leapfrog = 40 in 3.13 mins
# HMC acceptance = 63.8 percent; n_leapfrog = 45 in 3.5 mins
# HMC acceptance = 73.0 percent; n_leapfrog = 50 in 3.87 mins
# Total time = 6.16
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.46 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.84 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.21 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.59 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.97 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 2.38 mins
# HMC acceptance = 1.2 percent; n_leapfrog = 35 in 2.71 mins
# HMC acceptance = 45.0 percent; n_leapfrog = 40 in 3.08 mins
# HMC acceptance = 58.6 percent; n_leapfrog = 45 in 3.62 mins
# HMC acceptance = 68.0 percent; n_leapfrog = 50 in 3.92 mins
# Total time = 6.6
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.47 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.86 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.23 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.59 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.95 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 2.41 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 35 in 2.74 mins
# HMC acceptance = 7.4 percent; n_leapfrog = 40 in 3.09 mins
# HMC acceptance = 52.8 percent; n_leapfrog = 45 in 3.39 mins
# HMC acceptance = 61.4 percent; n_leapfrog = 50 in 3.63 mins

# %%
total_times_optimal = [2.2, 2.64, 3.08, 3.52, 3.96, 4.4, 4.84, 5.28, 5.72, 6.16]
n_leapfrog_optimal =  [18 , 22  , 25  , 28  , 30  , 34 , 39  , 42  , 46  , 49 ]
T = 5000
Metropolise = true
Print = false

for (i,total_time) in enumerate(total_times_optimal) 
    start = time()
    prior = SS_prior(d, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    xi_samples_hmc, hyper_samples_hmc, acc =
    GibbsHMC(my_model, ξ0, total_time/n_leapfrog_optimal[i], n_leapfrog_optimal[i], T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog_optimal[i], " in ", round((time()-start)/60,2), " mins \n")
    filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/GibbsHMC:d:"*string(d)*"-Nobs:"*string(Nobs)*
                "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog_optimal[i])*".jld"
    save(filename, "xi_samples", xi_samples_hmc, "hyper_samples", hyper_samples_hmc, "acc", acc)
    xi_samples_hmc, hyper_samples_hmc, acc = [], [], []
    gc()
end
# Out:
# HMC acceptance = 64.56 percent; n_leapfrog = 18 in 14.58 mins
# HMC acceptance = 64.68 percent; n_leapfrog = 22 in 17.31 mins
# HMC acceptance = 64.02 percent; n_leapfrog = 25 in 19.36 mins
# HMC acceptance = 62.02 percent; n_leapfrog = 28 in 21.58 mins
# HMC acceptance = 60.76 percent; n_leapfrog = 30 in 23.1 mins
# HMC acceptance = 60.6 percent; n_leapfrog = 34 in 26.11 mins
# HMC acceptance = 66.84 percent; n_leapfrog = 39 in 29.66 mins
# HMC acceptance = 66.14 percent; n_leapfrog = 42 in 30.29 mins
# HMC acceptance = 65.76 percent; n_leapfrog = 46 in 33.17 mins
# HMC acceptance = 64.88 percent; n_leapfrog = 49 in 35.31 mins

# %%
total_times_optimal = [2.2, 2.64, 3.08, 3.52, 3.96, 4.4, 4.84, 5.28, 5.72, 6.16]
n_leapfrog_optimal =  [18 , 22  , 25  , 28  , 30  , 34 , 39  , 42  , 46  , 49 ]
T = 5000
# Out:
# 5000

# %%
maxlag_hmc = 50
fig = figure(figsize=(12,4))
acfs_hmc = zeros(length(total_times_optimal),d,maxlag_hmc)

for i in 1:2 
    for j in 1:5
        k = 5*(i-1)+j
        total_time, n_leapfrog = total_times_optimal[k], n_leapfrog_optimal[k]
        filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/GibbsHMC:d:"*string(d)*"-Nobs:"*string(Nobs)*
                   "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog)*".jld"
        xi_samples_hmc = load(filename, "xi_samples")

        .0
        subplot(2,5,k)
        for dim in 1:size(xi_samples_hmc,1) 
            a = acf(xi_samples_hmc[dim,:], maxlag_hmc)
            plot(a)
            acfs_hmc[k,dim,:] = a
        end
        grid(true)  
        title("Total time:"*string(total_time)*", \n n_leapfrog:"*string(n_leapfrog), fontsize=10)
        xi_samples_hmc = []
        gc()
        if i == 2 xlabel("Lag") end
        if i == 1 xticks(alpha=0) end
        if j == 1 ylabel("ACF") end
        subplots_adjust(hspace=0.4)
    end
end
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x400 with 10 Axes>)

# %%
maxlag_hmc_list = [30, 40, 50, 30, 15, 10, 20, 15, 20, 15]
hmc_mixing = zeros(length(total_times_optimal))
for i in 1:length(total_times_optimal)
    hmc_mixing[i] = T/maximum(sum(acfs_hmc[i,:,1:maxlag_hmc_list[i]],2))
end
hmc_cost = T*n_leapfrog_optimal*Nobs;

# %%
mb_size = 1
max_attempts = 10^7
lambda = 2e1

fig = figure("pyplot_barplot",figsize=(5,3))
n_samples = 10^4
maxlag_gzz = 500
acfs_gzz = zeros(d,maxlag_gzz)
discard = 0
filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/lambda:"*string(lambda)*
            "-d:"*string(d)*"-Nobs:"*string(Nobs)*"-mb_size:"*string(mb_size)*".jld"
xt_skel, bt_skel = load(filename, "xt_skeleton", "bt_skeleton")
xi_samples_gzz = extract_samples(xt_skel[:,discard+1:end], 
                             bt_skel[:,discard+1:end], 
                            (bt_skel[end]-bt_skel[discard+1])/n_samples,
                            "linear")[:,1:end-1]
iacts_gzz = zeros(size(xi_samples_gzz,1))
for dim in 1:size(xi_samples_gzz,1)
    a = acf(xi_samples_gzz[dim,:],maxlag_gzz)
    plot(a)
    acfs_gzz[dim,:] = a
end
title("ACFs for GZZ")
xlabel("Lag")
ylabel("ACF")
grid(true)
xt_skel, bt_skel, xi_samples = [], [], []
gc()
# Out:
# PyPlot.Figure(PyObject <Figure size 500x300 with 1 Axes>)

# %%
gzz_mixing = n_samples/maximum(sum(acfs_gzz[:,1:100],2))
gzz_cost = max_attempts*mb_size;

# %%
minimum((gzz_mixing/gzz_cost)./(hmc_mixing./hmc_cost))
# Out:
# 2.5517543402418794
