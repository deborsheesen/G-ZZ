# %%
using Distributions, TimeIt, ProgressMeter, PyPlot, JLD
include("/home/postdoc/dsen/Desktop/codes/G-ZZ_clean/jl_files/zz_samplers.jl")
include("temp.jl")
# Out:
# run_sampler (generic function with 4 methods)

# %%
X, y = load("shrinkage_data_2.9.jld", "X", "y")
d, Nobs = size(X)
σ02 = 1
my_pr = SS_prior(d, σ02)
my_ll = ll_logistic_sp(X,y)
my_model = model(my_ll, my_pr)
print("d = ",  d, ", N = ", Nobs)
# Out:
# d = 101, N = 900

# %% [markdown]
# ### HMC:

# %% [markdown]
# ### Tune HMC:

# %%
ξ0 = randn(d)
Total_time = 10
T = 250
Metropolise = false
Print = false
n_leapfrog_list = 20*(1:5)
prior = SS_prior(d, σ02);

# %%
xi_samples_hmc, hyper_samples_hmc, acc = 
zeros(d,T+1,length(n_leapfrog_list)), zeros(hyperparam_size(prior),T+1,length(n_leapfrog_list)), 
zeros(length(n_leapfrog_list));

# %%
for (i,n_leapfrog) in enumerate(reverse(n_leapfrog_list))
    start = time()
    prior = SS_prior(d, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    stepsize = Total_time/n_leapfrog
    xi_samples_hmc[:,:,i], hyper_samples_hmc[:,:,i], acc[i] = 
    GibbsHMC(my_model, ξ0, stepsize, n_leapfrog, T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
end
# Out:
# HMC acceptance = 100.0 percent; n_leapfrog = 100 in 3.98 mins
# HMC acceptance = 100.0 percent; n_leapfrog = 80 in 3.25 mins
# HMC acceptance = 100.0 percent; n_leapfrog = 60 in 2.45 mins
# ArgumentError: InverseGamma: the condition α > zero(α) && θ > zero(θ) is not satisfied.
#
# Stacktrace:
#  [1] macro expansion at /home/postdoc/dsen/.julia/v0.6/Distributions/src/utils.jl:6 [inlined]
#  [2] Distributions.InverseGamma{Float64}(::Float64, ::Float64) at /home/postdoc/dsen/.julia/v0.6/Distributions/src/univariate/continuous/inversegamma.jl:33
#  [3] (::##505#511{SS_prior,Array{Float64,1}})(::Int64) at ./<missing>:0
#  [4] collect(::Base.Generator{UnitRange{Int64},##505#511{SS_prior,Array{Float64,1}}}) at ./array.jl:470
#  [5] block_Gibbs_update_hyperparams(::SS_prior, ::Array{Float64,1}) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/priors.jl:152
#  [6] GibbsHMC(::model, ::Array{Float64,1}, ::Float64, ::Int64, ::Int64, ::Bool, ::Bool) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl:634
#  [7] macro expansion at ./In[5]:7 [inlined]
#  [8] anonymous at ./<missing>:?
#  [9] include_string(::String, ::String) at ./loading.jl:522

# %%
Metropolise = true 
Print = false

stepsize = Total_time/50
total_times = 2.0*stepsize*(5:15)
n_leapfrog_steps = 5*(1:10)

for total_time in total_times
    print("Total time = ", round(total_time,2), "\n")
    for n_leapfrog in n_leapfrog_steps
        start = time()
        prior = SS_prior(d, σ02)
        my_ll = ll_logistic_sp(X,y)
        my_model = model(my_ll, prior)
        a, b, c = 
        GibbsHMC(my_model, ξ0, total_time/n_leapfrog, n_leapfrog, 500, Metropolise, Print)
        print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
    end
end
# Out:
# Total time = 2.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.49 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 10 in 0.88 mins
# HMC acceptance = 37.2 percent; n_leapfrog = 15 in 1.31 mins
# HMC acceptance = 80.4 percent; n_leapfrog = 20 in 1.71 mins
# HMC acceptance = 82.6 percent; n_leapfrog = 25 in 2.16 mins
# HMC acceptance = 87.8 percent; n_leapfrog = 30 in 2.48 mins
# HMC acceptance = 94.2 percent; n_leapfrog = 35 in 2.84 mins
# HMC acceptance = 95.6 percent; n_leapfrog = 40 in 3.18 mins
# HMC acceptance = 94.0 percent; n_leapfrog = 45 in 3.66 mins
# HMC acceptance = 96.2 percent; n_leapfrog = 50 in 3.98 mins
# Total time = 2.4
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.47 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.85 mins
# HMC acceptance = 0.8 percent; n_leapfrog = 15 in 1.22 mins
# HMC acceptance = 61.4 percent; n_leapfrog = 20 in 1.59 mins
# HMC acceptance = 77.4 percent; n_leapfrog = 25 in 2.04 mins
# HMC acceptance = 86.0 percent; n_leapfrog = 30 in 2.49 mins
# HMC acceptance = 90.8 percent; n_leapfrog = 35 in 2.79 mins
# HMC acceptance = 93.0 percent; n_leapfrog = 40 in 3.16 mins
# HMC acceptance = 94.0 percent; n_leapfrog = 45 in 3.53 mins
# HMC acceptance = 95.4 percent; n_leapfrog = 50 in 3.92 mins
# Total time = 2.8
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.48 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.86 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 15 in 1.25 mins
# HMC acceptance = 26.6 percent; n_leapfrog = 20 in 1.63 mins
# HMC acceptance = 57.8 percent; n_leapfrog = 25 in 2.02 mins
# HMC acceptance = 75.8 percent; n_leapfrog = 30 in 2.41 mins
# HMC acceptance = 80.6 percent; n_leapfrog = 35 in 2.84 mins
# HMC acceptance = 89.2 percent; n_leapfrog = 40 in 3.23 mins
# HMC acceptance = 93.0 percent; n_leapfrog = 45 in 3.58 mins
# HMC acceptance = 94.2 percent; n_leapfrog = 50 in 3.9 mins
# Total time = 3.2
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.5 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.86 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 15 in 1.21 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 20 in 1.61 mins
# HMC acceptance = 55.2 percent; n_leapfrog = 25 in 1.97 mins
# HMC acceptance = 64.4 percent; n_leapfrog = 30 in 2.35 mins
# HMC acceptance = 75.4 percent; n_leapfrog = 35 in 2.86 mins
# HMC acceptance = 82.4 percent; n_leapfrog = 40 in 3.27 mins
# HMC acceptance = 90.2 percent; n_leapfrog = 45 in 3.57 mins
# HMC acceptance = 91.4 percent; n_leapfrog = 50 in 4.02 mins
# Total time = 3.6
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.46 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.84 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.22 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 20 in 1.62 mins
# HMC acceptance = 4.2 percent; n_leapfrog = 25 in 1.98 mins
# HMC acceptance = 59.4 percent; n_leapfrog = 30 in 2.36 mins
# HMC acceptance = 79.4 percent; n_leapfrog = 35 in 2.75 mins
# HMC acceptance = 74.2 percent; n_leapfrog = 40 in 3.13 mins
# HMC acceptance = 85.0 percent; n_leapfrog = 45 in 3.51 mins
# HMC acceptance = 88.4 percent; n_leapfrog = 50 in 3.89 mins
# Total time = 4.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.46 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.85 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.25 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 20 in 1.61 mins
# HMC acceptance = 1.0 percent; n_leapfrog = 25 in 1.97 mins
# HMC acceptance = 42.0 percent; n_leapfrog = 30 in 2.36 mins
# HMC acceptance = 62.2 percent; n_leapfrog = 35 in 2.76 mins
# HMC acceptance = 75.4 percent; n_leapfrog = 40 in 3.29 mins
# HMC acceptance = 76.2 percent; n_leapfrog = 45 in 3.68 mins
# HMC acceptance = 85.6 percent; n_leapfrog = 50 in 3.88 mins
# Total time = 4.4
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.46 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.84 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.21 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 20 in 1.68 mins
# HMC acceptance = 0.8 percent; n_leapfrog = 25 in 2.02 mins
# HMC acceptance = 1.8 percent; n_leapfrog = 30 in 2.37 mins
# HMC acceptance = 55.4 percent; n_leapfrog = 35 in 2.74 mins
# HMC acceptance = 63.4 percent; n_leapfrog = 40 in 3.23 mins
# HMC acceptance = 78.0 percent; n_leapfrog = 45 in 3.57 mins
# HMC acceptance = 79.8 percent; n_leapfrog = 50 in 3.93 mins
# Total time = 4.8
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.47 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.88 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.27 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.74 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 25 in 2.07 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 30 in 2.57 mins
# HMC acceptance = 36.0 percent; n_leapfrog = 35 in 2.83 mins
# HMC acceptance = 57.2 percent; n_leapfrog = 40 in 3.21 mins
# HMC acceptance = 70.2 percent; n_leapfrog = 45 in 3.64 mins
# HMC acceptance = 77.8 percent; n_leapfrog = 50 in 3.9 mins
# Total time = 5.2
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.46 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.85 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.23 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.6 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.98 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 2.39 mins
# HMC acceptance = 1.6 percent; n_leapfrog = 35 in 2.75 mins
# HMC acceptance = 50.0 percent; n_leapfrog = 40 in 3.14 mins
# HMC acceptance = 60.0 percent; n_leapfrog = 45 in 3.51 mins
# HMC acceptance = 72.8 percent; n_leapfrog = 50 in 3.91 mins
# Total time = 5.6
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.46 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.85 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.26 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.61 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 1.99 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 30 in 2.38 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 35 in 2.84 mins
# HMC acceptance = 21.4 percent; n_leapfrog = 40 in 3.3 mins
# HMC acceptance = 57.0 percent; n_leapfrog = 45 in 3.59 mins
# HMC acceptance = 64.2 percent; n_leapfrog = 50 in 3.96 mins
# Total time = 6.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.46 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.85 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 1.3 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 1.65 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 2.0 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 2.38 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 35 in 2.74 mins
# HMC acceptance = 1.0 percent; n_leapfrog = 40 in 2.95 mins
# HMC acceptance = 46.0 percent; n_leapfrog = 45 in 3.31 mins
# HMC acceptance = 62.0 percent; n_leapfrog = 50 in 3.63 mins

# %%
total_times_optimal = [2.0, 2.4, 2.8, 3.2, 3.6, 4.0, 4.4, 4.8, 5.2, 5.6]
n_leapfrog_optimal =  [18 , 22 , 25 , 30 , 32 , 36 , 41 , 43 , 47 , 50 ]
T = 5000
Metropolise = true
Print = false

for (i,total_time) in enumerate(total_times_optimal) 
    start = time()
    prior = SS_prior(d, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    xi_samples_hmc, hyper_samples_hmc, acc =
    GibbsHMC(my_model, ξ0, total_time/n_leapfrog_optimal[i], n_leapfrog_optimal[i], T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog_optimal[i], " in ", round((time()-start)/60,2), " mins \n")
    filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/GibbsHMC:d:"*string(d)*"-Nobs:"*string(Nobs)*
                "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog_optimal[i])*".jld"
    save(filename, "xi_samples", xi_samples_hmc, "hyper_samples", hyper_samples_hmc, "acc", acc)
    xi_samples_hmc, hyper_samples_hmc, acc = [], [], []
    gc()
end
# Out:
# HMC acceptance = 64.1 percent; n_leapfrog = 18 in 15.27 mins
# HMC acceptance = 65.88 percent; n_leapfrog = 22 in 18.13 mins
# HMC acceptance = 61.58 percent; n_leapfrog = 25 in 20.24 mins
# HMC acceptance = 67.9 percent; n_leapfrog = 30 in 24.17 mins
# HMC acceptance = 64.38 percent; n_leapfrog = 32 in 25.72 mins
# HMC acceptance = 65.04 percent; n_leapfrog = 36 in 28.71 mins
# HMC acceptance = 66.0 percent; n_leapfrog = 41 in 31.34 mins
# HMC acceptance = 68.14 percent; n_leapfrog = 43 in 31.87 mins
# HMC acceptance = 68.34 percent; n_leapfrog = 47 in 34.93 mins
# HMC acceptance = 64.9 percent; n_leapfrog = 50 in 36.79 mins

# %%
total_times_optimal = [2.0, 2.4, 2.8, 3.2, 3.6, 4.0, 4.4, 4.8, 5.2, 5.6]
n_leapfrog_optimal =  [18 , 22 , 25 , 30 , 32 , 36 , 41 , 43 , 47 , 50 ]
T = 5000
# Out:
# 5000

# %%
maxlag_hmc = 50
fig = figure(figsize=(12,4))
acfs_hmc = zeros(length(total_times_optimal),d,maxlag_hmc)

for i in 1:2 
    for j in 1:5
        k = 5*(i-1)+j
        total_time, n_leapfrog = total_times_optimal[k], n_leapfrog_optimal[k]
        filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/GibbsHMC:d:"*string(d)*"-Nobs:"*string(Nobs)*
                   "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog)*".jld"
        xi_samples_hmc = load(filename, "xi_samples")

        .0
        subplot(2,5,k)
        for dim in 1:size(xi_samples_hmc,1) 
            a = acf(xi_samples_hmc[dim,:], maxlag_hmc)
            plot(a)
            acfs_hmc[k,dim,:] = a
        end
        grid(true)  
        title("Total time:"*string(total_time)*", \n n_leapfrog:"*string(n_leapfrog), fontsize=10)
        xi_samples_hmc = []
        gc()
        if i == 2 xlabel("Lag") end
        if i == 1 xticks(alpha=0) end
        if j == 1 ylabel("ACF") end
        subplots_adjust(hspace=0.4)
    end
end
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x400 with 10 Axes>)

# %%
maxlag_hmc_list = [40, 40, 25, 20, 10, 10, 10, 15, 10, 50]
hmc_mixing = zeros(length(total_times_optimal))
for i in 1:10
    hmc_mixing[i] = T/maximum(sum(acfs_hmc[i,:,1:maxlag_hmc_list[i]],2))
end
hmc_cost = T*n_leapfrog_optimal*Nobs;

# %%
mb_size = 1
max_attempts = 10^7
lambda = 2e1

fig = figure("pyplot_barplot",figsize=(5,3))
n_samples = 10^4
maxlag_gzz = 500
acfs_gzz = zeros(d,maxlag_gzz)
discard = 0
filename  = "/xtmp/GZZ_data/shrinkage_prior/synthetic_data/lambda:"*string(lambda)*
            "-d:"*string(d)*"-Nobs:"*string(Nobs)*"-mb_size:"*string(mb_size)*".jld"
xt_skel, bt_skel = load(filename, "xt_skeleton", "bt_skeleton")
xi_samples_gzz = extract_samples(xt_skel[:,discard+1:end], 
                             bt_skel[:,discard+1:end], 
                            (bt_skel[end]-bt_skel[discard+1])/n_samples,
                            "linear")[:,1:end-1]
iacts_gzz = zeros(size(xi_samples_gzz,1))
for dim in 1:size(xi_samples_gzz,1)
    a = acf(xi_samples_gzz[dim,:],maxlag_gzz)
    plot(a)
    acfs_gzz[dim,:] = a
end
title("ACFs for GZZ")
xlabel("Lag")
ylabel("ACF")
grid(true)
xt_skel, bt_skel, xi_samples = [], [], []
gc()
# Out:
# PyPlot.Figure(PyObject <Figure size 500x300 with 1 Axes>)

# %%
gzz_mixing = n_samples/maximum(sum(acfs_gzz[:,1:80],2))
gzz_cost = max_attempts*mb_size;

# %%
minimum((gzz_mixing/gzz_cost)./(hmc_mixing./hmc_cost))
# Out:
# 2.260937778195791

# %%
(gzz_mixing/gzz_cost)./(hmc_mixing./hmc_cost)
# Out:
# 10-element Array{Float64,1}:
#    7.00718
#    8.75942
#    8.03233
#    2.26094
#    3.1731
#    3.90739
#    4.98873
#    6.45376
#    6.93254
#  101.434
