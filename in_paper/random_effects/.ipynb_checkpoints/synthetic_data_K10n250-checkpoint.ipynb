# %%
using Distributions, TimeIt, ProgressMeter, PyPlot
include("/home/postdoc/dsen/Desktop/codes/G-ZZ_clean/jl_files/zz_samplers.jl")
include("temp.jl")
# Out:
# run_sampler (generic function with 3 methods)

# %% [markdown]
# #### Simulate data:

# %%
n_groups, group_size = 10, 250
Nobs = group_size*n_groups
d = 5
dim_total = 1+n_groups+d

σ02 = 1
my_pr = MM_prior(d, n_groups, σ02);

# %%
pX = 1e-1
X = spzeros(dim_total, Nobs)
X[1,:] = 1
for group in 1:n_groups
    X[group+1,((group-1)*group_size+1):(group*group_size)] = 1
end
X[n_groups+2:end,:] = sprandn(d, Nobs, pX)
ξ_true = rand(Normal(),dim_total)
y = Float64.([rand(Binomial(1, 1/(1+exp(-ξ_true'X[:,j])))) for j in 1:Nobs])
my_ll = ll_logistic_sp(X,y)
my_model = model(my_ll, my_pr);

# %% [markdown]
# ### Run GZZ sampler:

# %%
mb_size = 1
max_attempts = 10^7
prob_het = 0.95
adapt_speed = "none"

lambda = 5e1
start = time()
Print = true
run_sampler(my_model, lambda, max_attempts, mb_size, Print, prob_het, adapt_speed)
print("Time = ", round((time()-start)/60,1), " mins")
# Out:
# 10 percent attempts in 2.26 min; zz bounces = 75516, hyp bounces = 3792, total time of process = 75.191
# 20 percent attempts in 4.57 min; zz bounces = 150469, hyp bounces = 7673, total time of process = 150.459
# 30 percent attempts in 6.92 min; zz bounces = 225317, hyp bounces = 11425, total time of process = 225.669
# 40 percent attempts in 9.31 min; zz bounces = 300343, hyp bounces = 15112, total time of process = 300.714
# 50 percent attempts in 11.83 min; zz bounces = 374741, hyp bounces = 18848, total time of process = 375.877
# 60 percent attempts in 14.30 min; zz bounces = 449420, hyp bounces = 22610, total time of process = 451.270
# 70 percent attempts in 16.76 min; zz bounces = 524744, hyp bounces = 26435, total time of process = 526.402
# 80 percent attempts in 19.28 min; zz bounces = 599985, hyp bounces = 30185, total time of process = 601.564
# 90 percent attempts in 21.78 min; zz bounces = 674740, hyp bounces = 33884, total time of process = 676.762
# 100 percent attempts in 24.19 min; zz bounces = 749128, hyp bounces = 37735, total time of process = 751.940
# Time = 24.3 mins

# %% [markdown]
# ### Plot ACFs:

# %%
fig = figure("pyplot_barplot",figsize=(5,3))
n_samples = 10^4
maxlag_gzz = 400
acfs_gzz = zeros(dim_total,maxlag_gzz)
discard = 0
filename = "/xtmp/GZZ_data/mixed_effects/lambda:"*string(lambda)*
        "-dim_cov:"*string(d)*"-n_groups:"*string(n_groups)*
        "-Nobs:"*string(Nobs)*"-mb_size:"*string(mb_size)*".jld"
xt_skel, bt_skel = load(filename, "xt_skeleton", "bt_skeleton")
xi_samples_gzz = extract_samples(xt_skel[:,discard+1:end], 
                             bt_skel[:,discard+1:end], 
                            (bt_skel[end]-bt_skel[discard+1])/n_samples,
                            "linear")[:,1:end-1]
for dim in 1:size(xi_samples_gzz,1)
    a = acf(xi_samples_gzz[dim,:],maxlag_gzz)
    plot(a)
    acfs_gzz[dim,:] = a
end
grid(true)
xt_skel, bt_skel, xi_samples = [], [], []
gc()
# Out:
# PyPlot.Figure(PyObject <Figure size 500x300 with 1 Axes>)

# %% [markdown]
# ### Tune HMC:

# %%
ξ0 = randn(dim_total)
Total_time = 5
T = 250
Metropolise = false
Print = false
n_leapfrog_list = 25*(1:5)
# Out:
# 25:25:125

# %%
for (i,n_leapfrog) in enumerate(reverse(n_leapfrog_list))
    start = time()
    prior = MM_prior(d, n_groups, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    stepsize = Total_time/n_leapfrog
    xi_samples, hyper_samples, acc = 
    GibbsHMC(my_model, ξ0, stepsize, n_leapfrog, T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
end
# Out:
# HMC acceptance = 100.0 percent; n_leapfrog = 125 in 0.88 mins
# HMC acceptance = 100.0 percent; n_leapfrog = 100 in 0.7 mins
# HMC acceptance = 100.0 percent; n_leapfrog = 75 in 0.54 mins
# ArgumentError: Gamma: the condition α > zero(α) && θ > zero(θ) is not satisfied.
#
# Stacktrace:
#  [1] macro expansion at /home/postdoc/dsen/.julia/v0.6/Distributions/src/utils.jl:6 [inlined]
#  [2] Distributions.Gamma{Float64}(::Float64, ::Float64) at /home/postdoc/dsen/.julia/v0.6/Distributions/src/univariate/continuous/gamma.jl:32
#  [3] block_Gibbs_update_hyperparams(::MM_prior, ::Array{Float64,1}) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/priors.jl:329
#  [4] GibbsHMC(::model, ::Array{Float64,1}, ::Float64, ::Int64, ::Int64, ::Bool, ::Bool) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl:634
#  [5] macro expansion at ./In[8]:7 [inlined]
#  [6] anonymous at ./<missing>:?
#  [7] include_string(::String, ::String) at ./loading.jl:522

# %%
Metropolise = true 
Print = false

stepsize = Total_time/70
total_times = 4*stepsize*(6:15)
n_leapfrog_steps = 5*(1:10)

for total_time in total_times
    print("Total time = ", round(total_time,2), "\n")
    for n_leapfrog in n_leapfrog_steps
        start = time()
        prior = MM_prior(d, n_groups, σ02)
        my_ll = ll_logistic_sp(X,y)
        my_model = model(my_ll, prior)
        a, b, c = 
        GibbsHMC(my_model, ξ0, total_time/n_leapfrog, n_leapfrog, 500, Metropolise, Print)
        print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
    end
end
# Out:
# Total time = 1.71
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.09 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.16 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.23 mins
# HMC acceptance = 58.6 percent; n_leapfrog = 20 in 0.3 mins
# HMC acceptance = 85.8 percent; n_leapfrog = 25 in 0.37 mins
# HMC acceptance = 94.2 percent; n_leapfrog = 30 in 0.44 mins
# HMC acceptance = 94.4 percent; n_leapfrog = 35 in 0.51 mins
# HMC acceptance = 97.2 percent; n_leapfrog = 40 in 0.58 mins
# HMC acceptance = 97.8 percent; n_leapfrog = 45 in 0.68 mins
# HMC acceptance = 98.4 percent; n_leapfrog = 50 in 0.73 mins
# Total time = 2.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.09 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.16 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.23 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 20 in 0.3 mins
# HMC acceptance = 66.2 percent; n_leapfrog = 25 in 0.37 mins
# HMC acceptance = 89.2 percent; n_leapfrog = 30 in 0.45 mins
# HMC acceptance = 92.4 percent; n_leapfrog = 35 in 0.52 mins
# HMC acceptance = 94.8 percent; n_leapfrog = 40 in 0.59 mins
# HMC acceptance = 95.4 percent; n_leapfrog = 45 in 0.67 mins
# HMC acceptance = 95.6 percent; n_leapfrog = 50 in 0.75 mins
# Total time = 2.29
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.09 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.16 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.23 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.31 mins
# HMC acceptance = 9.0 percent; n_leapfrog = 25 in 0.38 mins
# HMC acceptance = 76.2 percent; n_leapfrog = 30 in 0.45 mins
# HMC acceptance = 88.4 percent; n_leapfrog = 35 in 0.52 mins
# HMC acceptance = 93.0 percent; n_leapfrog = 40 in 0.59 mins
# HMC acceptance = 94.8 percent; n_leapfrog = 45 in 0.67 mins
# HMC acceptance = 95.8 percent; n_leapfrog = 50 in 0.74 mins
# Total time = 2.57
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.09 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.16 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.24 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.31 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.38 mins
# HMC acceptance = 64.6 percent; n_leapfrog = 30 in 0.45 mins
# HMC acceptance = 82.8 percent; n_leapfrog = 35 in 0.53 mins
# HMC acceptance = 90.6 percent; n_leapfrog = 40 in 0.59 mins
# HMC acceptance = 91.2 percent; n_leapfrog = 45 in 0.66 mins
# HMC acceptance = 93.8 percent; n_leapfrog = 50 in 0.73 mins
# Total time = 2.86
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.09 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.16 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.23 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.3 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.37 mins
# HMC acceptance = 1.0 percent; n_leapfrog = 30 in 0.44 mins
# HMC acceptance = 67.8 percent; n_leapfrog = 35 in 0.52 mins
# HMC acceptance = 90.2 percent; n_leapfrog = 40 in 0.59 mins
# HMC acceptance = 91.0 percent; n_leapfrog = 45 in 0.68 mins
# HMC acceptance = 92.8 percent; n_leapfrog = 50 in 0.74 mins
# Total time = 3.14
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.09 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.16 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.23 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.31 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.38 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 0.45 mins
# HMC acceptance = 25.8 percent; n_leapfrog = 35 in 0.52 mins
# HMC acceptance = 72.0 percent; n_leapfrog = 40 in 0.59 mins
# HMC acceptance = 87.2 percent; n_leapfrog = 45 in 0.66 mins
# HMC acceptance = 92.8 percent; n_leapfrog = 50 in 0.74 mins
# Total time = 3.43
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.09 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.16 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.23 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.3 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.38 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 0.44 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 35 in 0.5 mins
# HMC acceptance = 59.4 percent; n_leapfrog = 40 in 0.58 mins
# HMC acceptance = 80.6 percent; n_leapfrog = 45 in 0.66 mins
# HMC acceptance = 88.4 percent; n_leapfrog = 50 in 0.73 mins
# Total time = 3.71
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.08 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.16 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.23 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.29 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.37 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 0.43 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 35 in 0.51 mins
# HMC acceptance = 3.2 percent; n_leapfrog = 40 in 0.59 mins
# HMC acceptance = 63.0 percent; n_leapfrog = 45 in 0.65 mins
# HMC acceptance = 84.4 percent; n_leapfrog = 50 in 0.72 mins
# Total time = 4.0
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.08 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.15 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.22 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.3 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.37 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 0.44 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 35 in 0.51 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 40 in 0.58 mins
# HMC acceptance = 38.6 percent; n_leapfrog = 45 in 0.66 mins
# HMC acceptance = 62.6 percent; n_leapfrog = 50 in 0.73 mins
# Total time = 4.29
# HMC acceptance = 0.0 percent; n_leapfrog = 5 in 0.09 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 10 in 0.16 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 15 in 0.23 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.3 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.38 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 0.45 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 35 in 0.52 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 40 in 0.6 mins
# HMC acceptance = 1.0 percent; n_leapfrog = 45 in 0.67 mins
# HMC acceptance = 61.8 percent; n_leapfrog = 50 in 0.75 mins

# %%
total_times_optimal = round.(total_times,2)
n_leapfrog_optimal =  [21,25,28,30,35,39,41,45,51,55];

# %%
T = 5000
Metropolise = true
Print = false

for (i,total_time) in enumerate(total_times_optimal) 
    n_leapfrog = n_leapfrog_optimal[i]
    start = time()
    prior = MM_prior(d, n_groups, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    xi_samples_hmc, hyper_samples_hmc, acc =
    GibbsHMC(my_model, ξ0, total_time/n_leapfrog, n_leapfrog, T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
    filename  = "/xtmp/GZZ_data/mixed_effects/GibbsHMC:d:"*
                string(d)*"-n_groups:"*string(n_groups)*"-Nobs:"*string(Nobs)*
                "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog)*".jld"
    save(filename, "xi_samples", xi_samples_hmc, "hyper_samples", hyper_samples_hmc, "acc", acc)
    xi_samples_hmc, hyper_samples_hmc, acc = [], [], []
    gc()
end
# Out:
# HMC acceptance = 68.94 percent; n_leapfrog = 21 in 3.19 mins
# HMC acceptance = 67.76 percent; n_leapfrog = 25 in 3.71 mins
# HMC acceptance = 68.42 percent; n_leapfrog = 28 in 4.14 mins
# HMC acceptance = 63.56 percent; n_leapfrog = 30 in 4.43 mins
# HMC acceptance = 71.68 percent; n_leapfrog = 35 in 5.13 mins
# HMC acceptance = 67.6 percent; n_leapfrog = 39 in 5.71 mins
# HMC acceptance = 69.44 percent; n_leapfrog = 41 in 5.94 mins
# HMC acceptance = 70.48 percent; n_leapfrog = 45 in 6.36 mins
# HMC acceptance = 66.88 percent; n_leapfrog = 51 in 7.2 mins
# HMC acceptance = 68.58 percent; n_leapfrog = 55 in 7.73 mins

# %%
maxlag_hmc = 50
fig = figure(figsize=(12,4))
acfs_hmc = zeros(length(total_times_optimal),dim_total,maxlag_hmc)

for i in 1:2 
    for j in 1:5
        k = 5*(i-1)+j
        total_time, n_leapfrog = total_times_optimal[k], n_leapfrog_optimal[k]
        filename  = "/xtmp/GZZ_data/mixed_effects/GibbsHMC:d:"*
                string(d)*"-n_groups:"*string(n_groups)*"-Nobs:"*string(Nobs)*
                "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog)*".jld"
        xi_samples_hmc = load(filename, "xi_samples")

        subplot(2,5,k)
        for dim in 1:size(xi_samples_hmc,1) 
            a = acf(xi_samples_hmc[dim,:], maxlag_hmc)
            plot(a)
            acfs_hmc[k,dim,:] = a
        end
        grid(true)  
        title("Total time:"*string(total_time)*", \n n_leapfrog:"*string(n_leapfrog), fontsize=10)
        xi_samples_hmc = []
        gc()
        if i == 2 xlabel("Lag") end
        if j == 1 ylabel("ACF") end
        subplots_adjust(hspace=0.5)
    end
end
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x400 with 10 Axes>)

# %%
T = 5000
maxlag_hmc_list = [50, 20, 25, 10, 25, 50, 35, 15, 20, 20]
hmc_mixing = zeros(length(total_times_optimal))
for i in 1:length(total_times_optimal)
    hmc_mixing[i] = T/maximum(sum(acfs_hmc[i,:,1:maxlag_hmc_list[i]],2))
end
hmc_cost = T*n_leapfrog_optimal*Nobs;

# %%
gzz_mixing = n_samples/maximum(sum(acfs_gzz[:,1:300],2))
gzz_cost = max_attempts*mb_size
minimum((gzz_mixing/gzz_cost)./(hmc_mixing./hmc_cost))
# Out:
# 1.1498395375142498

# %%
(gzz_mixing/gzz_cost)./(hmc_mixing./hmc_cost)
# Out:
# 10-element Array{Float64,1}:
#  15.2959
#   3.7614
#   5.49954
#   1.14984
#   9.19947
#  13.1408
#   9.12618
#   3.32666
#   3.05969
#   9.02689

# %%
k=5
total_time, n_leapfrog = total_times_optimal[k], n_leapfrog_optimal[k]
filename  = "/xtmp/GZZ_data/mixed_effects/GibbsHMC:d:"*
        string(d)*"-n_groups:"*string(n_groups)*"-Nobs:"*string(Nobs)*
        "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog)*".jld"
xi_samples_hmc, hyper_samples_hmc = load(filename, "xi_samples", "hyper_samples");

# %%
size(xi_samples_hmc)
# Out:
# (16, 5001)

# %%
fig = figure(figsize=(12,2.5))
for i in 1:8
    for j in 1:2
        k = (j-1)*8+i
        subplot(2,8,k)
        hist(xi_samples_hmc[k,:], density=true, bins=50)
#         grid(true)
    end
end
subplots_adjust(hspace=0.5)
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x250 with 16 Axes>)

# %%
mean(xi_samples_hmc,2)
# Out:
# 16×1 Array{Float64,2}:
#  -0.984705
#   0.00396715
#  -0.298673
#   0.333913
#   0.124698
#   0.506394
#  -0.415683
#  -0.02293
#  -0.522084
#  -0.620767
#  -0.0989715
#   0.375533
#   0.408167
#  -1.38292
#   0.353295
#   0.695113

# %%
std(xi_samples_hmc,2)
# Out:
# 16×1 Array{Float64,2}:
#  0.135768
#  0.209415
#  0.231017
#  0.228953
#  0.212504
#  0.24536
#  0.243652
#  0.205863
#  0.259145
#  0.292029
#  0.212147
#  0.226505
#  0.228325
#  0.325404
#  0.246505
#  0.286129
