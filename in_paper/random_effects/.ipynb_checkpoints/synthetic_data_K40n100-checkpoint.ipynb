# %%
using Distributions, TimeIt, ProgressMeter, PyPlot
include("/home/postdoc/dsen/Desktop/codes/G-ZZ_clean/jl_files/zz_samplers.jl")
include("temp.jl")
# Out:
# run_sampler (generic function with 3 methods)

# %% [markdown]
# #### Simulate data:

# %%
n_groups, group_size = 40, 100
Nobs = group_size*n_groups
d = 5
dim_total = 1+n_groups+d

σ02 = 1
my_pr = MM_prior(d, n_groups, σ02);

# %%
pX = 5e-2
X = spzeros(dim_total, Nobs)
X[1,:] = 1
for group in 1:n_groups
    X[group+1,((group-1)*group_size+1):(group*group_size)] = 1
end
X[n_groups+2:end,:] = sprandn(d, Nobs, pX)
ξ_true = rand(Normal(),dim_total)
y = Float64.([rand(Binomial(1, 1/(1+exp(-ξ_true'X[:,j])))) for j in 1:Nobs])
my_ll = ll_logistic_sp(X,y)
my_model = model(my_ll, my_pr);

# %% [markdown]
# ### Run GZZ sampler:

# %%
mb_size = 1
max_attempts = 2*10^7
prob_het = 0.99
adapt_speed = "none"

lambda = 5e1
start = time()
Print = true
run_sampler(my_model, lambda, max_attempts, mb_size, Print, prob_het, adapt_speed)
print("Time = ", round((time()-start)/60,1), " mins")
# Out:
# 10 percent attempts in 5.44 min; zz bounces = 220447, hyp bounces = 4917, total time of process = 98.860
# 20 percent attempts in 12.06 min; zz bounces = 441258, hyp bounces = 9797, total time of process = 197.769
# 30 percent attempts in 19.25 min; zz bounces = 661455, hyp bounces = 14799, total time of process = 296.784
# 40 percent attempts in 26.24 min; zz bounces = 882330, hyp bounces = 19711, total time of process = 395.853
# 50 percent attempts in 33.20 min; zz bounces = 1104363, hyp bounces = 24771, total time of process = 494.750
# 60 percent attempts in 40.37 min; zz bounces = 1325731, hyp bounces = 29871, total time of process = 593.727
# 70 percent attempts in 48.20 min; zz bounces = 1546641, hyp bounces = 34790, total time of process = 692.629
# 80 percent attempts in 57.16 min; zz bounces = 1766922, hyp bounces = 39687, total time of process = 791.598
# 90 percent attempts in 65.89 min; zz bounces = 1987440, hyp bounces = 44630, total time of process = 890.470
# 100 percent attempts in 74.29 min; zz bounces = 2207985, hyp bounces = 49648, total time of process = 989.352
# Time = 74.4 mins

# %% [markdown]
# ### Plot ACFs:

# %%
fig = figure("pyplot_barplot",figsize=(5,3))
n_samples = 10^4
maxlag_gzz = 200
acfs_gzz = zeros(dim_total,maxlag_gzz)
discard = 0
filename = "/xtmp/GZZ_data/mixed_effects/lambda:"*string(lambda)*
        "-dim_cov:"*string(d)*"-n_groups:"*string(n_groups)*
        "-Nobs:"*string(Nobs)*"-mb_size:"*string(mb_size)*".jld"
xt_skel, bt_skel = load(filename, "xt_skeleton", "bt_skeleton")
xi_samples_gzz = extract_samples(xt_skel[:,discard+1:end], 
                                 bt_skel[:,discard+1:end], 
                                 (bt_skel[end]-bt_skel[discard+1])/n_samples,
                                 "linear")[:,1:end-1]
for dim in 1:size(xi_samples_gzz,1)
    a = acf(xi_samples_gzz[dim,:],maxlag_gzz)
    plot(a)
    acfs_gzz[dim,:] = a
end
grid(true)
xt_skel, bt_skel, xi_samples = [], [], []
gc()
# Out:
# PyPlot.Figure(PyObject <Figure size 500x300 with 1 Axes>)

# %% [markdown]
# ### Tune HMC:

# %%
ξ0 = randn(dim_total)
Total_time = 4.5
T = 250
Metropolise = false
Print = false
n_leapfrog_list = 25*(1:5)
# Out:
# 25:25:125

# %%
for (i,n_leapfrog) in enumerate(reverse(n_leapfrog_list))
    start = time()
    prior = MM_prior(d, n_groups, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    stepsize = Total_time/n_leapfrog
    xi_samples, hyper_samples, acc = 
    GibbsHMC(my_model, ξ0, stepsize, n_leapfrog, T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
end
# Out:
# HMC acceptance = 100.0 percent; n_leapfrog = 125 in 2.08 mins
# ArgumentError: Gamma: the condition α > zero(α) && θ > zero(θ) is not satisfied.
#
# Stacktrace:
#  [1] macro expansion at /home/postdoc/dsen/.julia/v0.6/Distributions/src/utils.jl:6 [inlined]
#  [2] Distributions.Gamma{Float64}(::Float64, ::Float64) at /home/postdoc/dsen/.julia/v0.6/Distributions/src/univariate/continuous/gamma.jl:32
#  [3] block_Gibbs_update_hyperparams(::MM_prior, ::Array{Float64,1}) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/priors.jl:329
#  [4] GibbsHMC(::model, ::Array{Float64,1}, ::Float64, ::Int64, ::Int64, ::Bool, ::Bool) at /home/postdoc/dsen/Desktop/G-ZZ/jl_files/zz_samplers.jl:634
#  [5] macro expansion at ./In[15]:7 [inlined]
#  [6] anonymous at ./<missing>:?
#  [7] include_string(::String, ::String) at ./loading.jl:522

# %%
Metropolise = true 
Print = false

stepsize = Total_time/110
total_times = 6*stepsize*(6:15)
n_leapfrog_steps = 5*(4:10)

for total_time in total_times
    print("Total time = ", round(total_time,2), "\n")
    for n_leapfrog in n_leapfrog_steps
        start = time()
        prior = MM_prior(d, n_groups, σ02)
        my_ll = ll_logistic_sp(X,y)
        my_model = model(my_ll, prior)
        a, b, c = 
        GibbsHMC(my_model, ξ0, total_time/n_leapfrog, n_leapfrog, 500, Metropolise, Print)
        print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
        if c > 0.7 
            break
        end
    end
end
# Out:
# Total time = 1.47
# HMC acceptance = 1.0 percent; n_leapfrog = 20 in 0.64 mins
# HMC acceptance = 62.8 percent; n_leapfrog = 25 in 0.79 mins
# HMC acceptance = 89.0 percent; n_leapfrog = 30 in 0.94 mins
# Total time = 1.72
# HMC acceptance = 0.6 percent; n_leapfrog = 20 in 0.63 mins
# HMC acceptance = 1.0 percent; n_leapfrog = 25 in 0.79 mins
# HMC acceptance = 65.6 percent; n_leapfrog = 30 in 0.93 mins
# HMC acceptance = 83.4 percent; n_leapfrog = 35 in 1.08 mins
# Total time = 1.96
# HMC acceptance = 0.8 percent; n_leapfrog = 20 in 0.64 mins
# HMC acceptance = 1.2 percent; n_leapfrog = 25 in 0.79 mins
# HMC acceptance = 2.0 percent; n_leapfrog = 30 in 0.94 mins
# HMC acceptance = 78.4 percent; n_leapfrog = 35 in 1.09 mins
# Total time = 2.21
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.63 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 25 in 0.81 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 30 in 0.95 mins
# HMC acceptance = 7.6 percent; n_leapfrog = 35 in 1.1 mins
# HMC acceptance = 78.0 percent; n_leapfrog = 40 in 1.25 mins
# Total time = 2.45
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.63 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 25 in 0.8 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 30 in 0.94 mins
# HMC acceptance = 1.4 percent; n_leapfrog = 35 in 1.07 mins
# HMC acceptance = 34.2 percent; n_leapfrog = 40 in 1.21 mins
# HMC acceptance = 78.4 percent; n_leapfrog = 45 in 1.35 mins
# Total time = 2.7
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.61 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 25 in 0.77 mins
# HMC acceptance = 0.8 percent; n_leapfrog = 30 in 0.93 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 35 in 1.08 mins
# HMC acceptance = 0.8 percent; n_leapfrog = 40 in 1.22 mins
# HMC acceptance = 49.4 percent; n_leapfrog = 45 in 1.37 mins
# HMC acceptance = 83.6 percent; n_leapfrog = 50 in 1.51 mins
# Total time = 2.95
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.6 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.75 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 30 in 0.91 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 35 in 1.06 mins
# HMC acceptance = 0.8 percent; n_leapfrog = 40 in 1.2 mins
# HMC acceptance = 1.8 percent; n_leapfrog = 45 in 1.35 mins
# HMC acceptance = 71.4 percent; n_leapfrog = 50 in 1.49 mins
# Total time = 3.19
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.6 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.74 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 30 in 0.9 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 35 in 1.04 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 40 in 1.19 mins
# HMC acceptance = 1.2 percent; n_leapfrog = 45 in 1.33 mins
# HMC acceptance = 2.2 percent; n_leapfrog = 50 in 1.49 mins
# Total time = 3.44
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.6 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.74 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 30 in 0.89 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 35 in 1.06 mins
# HMC acceptance = 0.6 percent; n_leapfrog = 40 in 1.21 mins
# HMC acceptance = 1.0 percent; n_leapfrog = 45 in 1.35 mins
# HMC acceptance = 1.6 percent; n_leapfrog = 50 in 1.5 mins
# Total time = 3.68
# HMC acceptance = 0.0 percent; n_leapfrog = 20 in 0.6 mins
# HMC acceptance = 0.0 percent; n_leapfrog = 25 in 0.75 mins
# HMC acceptance = 0.2 percent; n_leapfrog = 30 in 0.9 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 35 in 1.07 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 40 in 1.21 mins
# HMC acceptance = 0.4 percent; n_leapfrog = 45 in 1.34 mins
# HMC acceptance = 1.0 percent; n_leapfrog = 50 in 1.45 mins

# %%
total_times_optimal = round.(total_times,2)
n_leapfrog_optimal =  [25,30,33,37,42,47,49,55,60,65];

# %%
T = 5000
Metropolise = true
Print = false

for (i,total_time) in enumerate(total_times_optimal) 
    n_leapfrog = n_leapfrog_optimal[i]
    start = time()
    prior = MM_prior(d, n_groups, σ02)
    my_ll = ll_logistic_sp(X,y)
    my_model = model(my_ll, prior)
    xi_samples_hmc, hyper_samples_hmc, acc =
    GibbsHMC(my_model, ξ0, total_time/n_leapfrog, n_leapfrog, T, Metropolise, Print)
    print("n_leapfrog = ", n_leapfrog, " in ", round((time()-start)/60,2), " mins \n")
    filename  = "/xtmp/GZZ_data/mixed_effects/GibbsHMC:d:"*
                string(d)*"-n_groups:"*string(n_groups)*"-Nobs:"*string(Nobs)*
                "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog)*".jld"
    save(filename, "xi_samples", xi_samples_hmc, "hyper_samples", hyper_samples_hmc, "acc", acc)
    xi_samples_hmc, hyper_samples_hmc, acc = [], [], []
    gc()
end
# Out:
# HMC acceptance = 67.0 percent; n_leapfrog = 25 in 7.73 mins
# HMC acceptance = 68.74 percent; n_leapfrog = 30 in 9.17 mins
# HMC acceptance = 64.82 percent; n_leapfrog = 33 in 12.97 mins
# HMC acceptance = 60.88 percent; n_leapfrog = 37 in 14.66 mins
# HMC acceptance = 62.76 percent; n_leapfrog = 42 in 16.52 mins
# HMC acceptance = 72.84 percent; n_leapfrog = 47 in 14.32 mins
# HMC acceptance = 52.72 percent; n_leapfrog = 49 in 14.68 mins
# HMC acceptance = 67.86 percent; n_leapfrog = 55 in 19.23 mins
# HMC acceptance = 75.98 percent; n_leapfrog = 60 in 22.81 mins
# HMC acceptance = 79.12 percent; n_leapfrog = 65 in 21.21 mins

# %%
maxlag_hmc = 100
fig = figure(figsize=(12,4))
acfs_hmc = zeros(length(total_times_optimal),dim_total,maxlag_hmc)

for i in 1:2 
    for j in 1:5
        k = 5*(i-1)+j
        total_time, n_leapfrog = total_times_optimal[k], n_leapfrog_optimal[k]
        filename  = "/xtmp/GZZ_data/mixed_effects/GibbsHMC:d:"*
                string(d)*"-n_groups:"*string(n_groups)*"-Nobs:"*string(Nobs)*
                "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog)*".jld"
        xi_samples_hmc = load(filename, "xi_samples")

        subplot(2,5,k)
        for dim in 1:size(xi_samples_hmc,1) 
            a = acf(xi_samples_hmc[dim,:], maxlag_hmc)
            plot(a)
            acfs_hmc[k,dim,:] = a
        end
        grid(true)  
        title("Total time:"*string(total_time)*", \n n_leapfrog:"*string(n_leapfrog), fontsize=10)
        xi_samples_hmc = []
        gc()
        if i == 2 xlabel("Lag") end
        if j == 1 ylabel("ACF") end
        subplots_adjust(hspace=0.5)
    end
end
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x400 with 10 Axes>)

# %%
T = 5000
maxlag_hmc_list = [75, 55, 85, 100, 80, 100, 100, 100, 100, 25]
hmc_mixing = zeros(length(total_times_optimal))
for i in 1:length(total_times_optimal)
    hmc_mixing[i] = T/maximum(sum(acfs_hmc[i,:,1:maxlag_hmc_list[i]],2))
end
hmc_cost = T*n_leapfrog_optimal*Nobs;

# %%
gzz_mixing = n_samples/maximum(sum(acfs_gzz[:,1:125],2))
gzz_cost = max_attempts*mb_size
minimum((gzz_mixing/gzz_cost)./(hmc_mixing./hmc_cost))
# Out:
# 15.370959933629948

# %%
(gzz_mixing/gzz_cost)./(hmc_mixing./hmc_cost)
# Out:
# 10-element Array{Float64,1}:
#  28.6187
#  38.1972
#  50.8736
#  47.9079
#  49.3112
#  27.032
#  68.2937
#  15.371
#  16.5284
#  20.349

# %%
k=5
total_time, n_leapfrog = total_times_optimal[k], n_leapfrog_optimal[k]
filename  = "/xtmp/GZZ_data/mixed_effects/GibbsHMC:d:"*
        string(d)*"-n_groups:"*string(n_groups)*"-Nobs:"*string(Nobs)*
        "-total_time:"*string(total_time)*"-n_leapfrog:"*string(n_leapfrog)*".jld"
xi_samples_hmc, hyper_samples_hmc = load(filename, "xi_samples", "hyper_samples");

# %%
size(xi_samples_hmc)
# Out:
# (16, 5001)

# %%
fig = figure(figsize=(12,2.5))
for i in 1:8
    for j in 1:2
        k = (j-1)*8+i
        subplot(2,8,k)
        hist(xi_samples_hmc[k,:], density=true, bins=50)
#         grid(true)
    end
end
subplots_adjust(hspace=0.5)
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x250 with 16 Axes>)

# %%
mean(xi_samples_hmc,2)
# Out:
# 16×1 Array{Float64,2}:
#  -0.984705
#   0.00396715
#  -0.298673
#   0.333913
#   0.124698
#   0.506394
#  -0.415683
#  -0.02293
#  -0.522084
#  -0.620767
#  -0.0989715
#   0.375533
#   0.408167
#  -1.38292
#   0.353295
#   0.695113

# %%
std(xi_samples_hmc,2)
# Out:
# 16×1 Array{Float64,2}:
#  0.135768
#  0.209415
#  0.231017
#  0.228953
#  0.212504
#  0.24536
#  0.243652
#  0.205863
#  0.259145
#  0.292029
#  0.212147
#  0.226505
#  0.228325
#  0.325404
#  0.246505
#  0.286129
